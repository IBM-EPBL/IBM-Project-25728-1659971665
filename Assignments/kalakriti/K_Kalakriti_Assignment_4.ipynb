# %% [markdown]
# **Importing** **the** **libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# **Reading** **the** **dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# **Process the data**

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,  14,  52, 399],
#        [  0,   0,   0, ...,  93,   8, 162],
#        [  0,   0,   0, ...,  23,  38, 142],
#        ...,
#        [  0,   0,   0, ..., 160, 345, 671],
#        [  0,   0,   0, ...,  63,  33, 262],
#        [  0,   0,   0, ...,  32,  50,  63]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: 'now',
#  20: '2',
#  21: 'are',
#  22: 'that',
#  23: 'so',
#  24: 'but',
#  25: 'not',
#  26: 'can',
#  27: 'at',
#  28: 'or',
#  29: 'ur',
#  30: 'do',
#  31: "i'm",
#  32: 'will',
#  33: 'with',
#  34: 'get',
#  35: 'be',
#  36: 'just',
#  37: 'if',
#  38: 'no',
#  39: 'this',
#  40: 'we',
#  41: 'gt',
#  42: 'lt',
#  43: 'when',
#  44: '4',
#  45: 'up',
#  46: 'ok',
#  47: 'how',
#  48: 'free',
#  49: 'from',
#  50: 'go',
#  51: 'what',
#  52: 'out',
#  53: 'all',
#  54: 'know',
#  55: 'like',
#  56: 'good',
#  57: 'got',
#  58: 'then',
#  59: 'am',
#  60: 'was',
#  61: 'only',
#  62: 'day',
#  63: 'time',
#  64: 'its',
#  65: 'come',
#  66: 'text',
#  67: 'send',
#  68: 'love',
#  69: 'there',
#  70: 'he',
#  71: 'want',
#  72: 'going',
#  73: 'one',
#  74: 'as',
#  75: 'need',
#  76: 'by',
#  77: 'txt',
#  78: 'home',
#  79: 'stop',
#  80: "i'll",
#  81: 'lor',
#  82: 'r',
#  83: 'about',
#  84: 'sorry',
#  85: 'still',
#  86: 'our',
#  87: 'today',
#  88: 'mobile',
#  89: 'see',
#  90: 'dont',
#  91: 'reply',
#  92: 'k',
#  93: 'back',
#  94: 'da',
#  95: 'she',
#  96: 'tell',
#  97: 'n',
#  98: 'hi',
#  99: 'later',
#  100: 'new',
#  101: "don't",
#  102: 'pls',
#  103: 'take',
#  104: 'been',
#  105: 'did',
#  106: 'any',
#  107: 'please',
#  108: 'dear',
#  109: 'they',
#  110: 'her',
#  111: 'phone',
#  112: 'some',
#  113: 'ì',
#  114: 'think',
#  115: 'week',
#  116: 'him',
#  117: 'hey',
#  118: 'well',
#  119: 'much',
#  120: 'here',
#  121: 'has',
#  122: 'claim',
#  123: 'where',
#  124: 'great',
#  125: 'oh',
#  126: 'night',
#  127: 'who',
#  128: 'happy',
#  129: 'd',
#  130: 'too',
#  131: 'had',
#  132: 'hope',
#  133: 'an',
#  134: 'msg',
#  135: '1',
#  136: 'more',
#  137: 'yes',
#  138: 'make',
#  139: 'www',
#  140: "it's",
#  141: 'way',
#  142: 'work',
#  143: 'number',
#  144: 'wat',
#  145: 'say',
#  146: 'should',
#  147: 'give',
#  148: 'message',
#  149: 'after',
#  150: 'right',
#  151: 'ask',
#  152: 'c',
#  153: 'prize',
#  154: 'e',
#  155: 'doing',
#  156: 'tomorrow',
#  157: 'im',
#  158: 'find',
#  159: 'already',
#  160: 'amp',
#  161: 'meet',
#  162: 'life',
#  163: 'cash',
#  164: 'really',
#  165: 'yeah',
#  166: 'last',
#  167: 'said',
#  168: 'them',
#  169: 'morning',
#  170: '3',
#  171: 't',
#  172: 'very',
#  173: 'lol',
#  174: 'would',
#  175: 'also',
#  176: 'cos',
#  177: 'why',
#  178: 'miss',
#  179: 'let',
#  180: 'over',
#  181: 'won',
#  182: 'babe',
#  183: 'thanks',
#  184: 'keep',
#  185: 'b',
#  186: 'sent',
#  187: 'min',
#  188: 'care',
#  189: 'win',
#  190: '150p',
#  191: 'every',
#  192: 'uk',
#  193: 'us',
#  194: 'again',
#  195: 'sure',
#  196: 'urgent',
#  197: 'pick',
#  198: 'com',
#  199: 'anything',
#  200: 'something',
#  201: 'buy',
#  202: 'contact',
#  203: 'before',
#  204: 'first',
#  205: 'were',
#  206: 's',
#  207: 'cant',
#  208: 'around',
#  209: 'tone',
#  210: 'feel',
#  211: 'place',
#  212: '50',
#  213: 'off',
#  214: 'money',
#  215: 'wait',
#  216: 'thing',
#  217: 'chat',
#  218: 'went',
#  219: 'which',
#  220: 'nokia',
#  221: "i've",
#  222: 'tonight',
#  223: 'per',
#  224: 'friends',
#  225: 'many',
#  226: '5',
#  227: 'someone',
#  228: 'co',
#  229: 'soon',
#  230: 'late',
#  231: 'other',
#  232: 'sleep',
#  233: 'dun',
#  234: 'told',
#  235: 'his',
#  236: 'down',
#  237: 'even',
#  238: 'customer',
#  239: 'gud',
#  240: 'wan',
#  241: 'wish',
#  242: 'service',
#  243: 'things',
#  244: 'could',
#  245: 'hello',
#  246: 'ìï',
#  247: 'getting',
#  248: 'next',
#  249: 'always',
#  250: 'ya',
#  251: 'x',
#  252: "you're",
#  253: 'nice',
#  254: '18',
#  255: "can't",
#  256: 'help',
#  257: 'fine',
#  258: 'special',
#  259: 'yet',
#  260: 'haha',
#  261: 'people',
#  262: 'v',
#  263: 'waiting',
#  264: 'leave',
#  265: 'coming',
#  266: 'same',
#  267: 'thk',
#  268: 'gonna',
#  269: 'sms',
#  270: 'name',
#  271: 'guaranteed',
#  272: 'few',
#  273: 'done',
#  274: '16',
#  275: 'friend',
#  276: 'smile',
#  277: "that's",
#  278: 'better',
#  279: 'use',
#  280: 'holiday',
#  281: 'live',
#  282: 'may',
#  283: 'days',
#  284: 'mins',
#  285: 'heart',
#  286: 'y',
#  287: 'talk',
#  288: '6',
#  289: 'thought',
#  290: 'try',
#  291: 'year',
#  292: 'class',
#  293: 'man',
#  294: "didn't",
#  295: 'lunch',
#  296: 'draw',
#  297: 'best',
#  298: 'cs',
#  299: 'line',
#  300: 'job',
#  301: 'meeting',
#  302: 'yup',
#  303: 'long',
#  304: 'lar',
#  305: 'stuff',
#  306: 'because',
#  307: 'dat',
#  308: '7',
#  309: 'house',
#  310: 'ready',
#  311: 'thats',
#  312: 'trying',
#  313: 'ah',
#  314: 'person',
#  315: 'month',
#  316: 'play',
#  317: 'end',
#  318: 'cool',
#  319: 'having',
#  320: 'problem',
#  321: 'mind',
#  322: 'latest',
#  323: 'being',
#  324: 'account',
#  325: 'bit',
#  326: 'real',
#  327: 'half',
#  328: 'guess',
#  329: 'wanna',
#  330: 'world',
#  331: 'never',
#  332: 'car',
#  333: 'awarded',
#  334: 'å£1',
#  335: 'than',
#  336: 'lot',
#  337: 'enjoy',
#  338: 'guys',
#  339: 'nothing',
#  340: 'camera',
#  341: 'girl',
#  342: 'chance',
#  343: 'eat',
#  344: 'ill',
#  345: 'sweet',
#  346: 'finish',
#  347: 'luv',
#  348: 'another',
#  349: 'yo',
#  350: 'box',
#  351: 'offer',
#  352: 'sir',
#  353: 'birthday',
#  354: 'bed',
#  355: '1st',
#  356: 'minutes',
#  357: 'room',
#  358: 'into',
#  359: 'word',
#  360: 'receive',
#  361: 'start',
#  362: 'dinner',
#  363: 'wk',
#  364: 'shows',
#  365: 'rate',
#  366: 'easy',
#  367: 'jus',
#  368: 'hear',
#  369: 'wont',
#  370: 'liao',
#  371: 'quite',
#  372: 'landline',
#  373: '150ppm',
#  374: 'called',
#  375: 'left',
#  376: 'bad',
#  377: 'watching',
#  378: 'ever',
#  379: 'cost',
#  380: 'aight',
#  381: 'shit',
#  382: 'thanx',
#  383: 'check',
#  384: 'early',
#  385: 'å£1000',
#  386: 'between',
#  387: '2nd',
#  388: 'bt',
#  389: 'reach',
#  390: 'dunno',
#  391: 'face',
#  392: 'baby',
#  393: 'xxx',
#  394: 'big',
#  395: 'two',
#  396: 'god',
#  397: 'ringtone',
#  398: 'pay',
#  399: "he's",
#  400: 'tmr',
#  401: 'watch',
#  402: 'look',
#  403: 'might',
#  404: 'pa',
#  405: 'network',
#  406: 'shall',
#  407: 'video',
#  408: 'once',
#  409: 'remember',
#  410: 'sat',
#  411: 'll',
#  412: 'hour',
#  413: '10',
#  414: 'orange',
#  415: 'g',
#  416: 'office',
#  417: 'forgot',
#  418: 'apply',
#  419: 'xmas',
#  420: 'part',
#  421: 'anyway',
#  422: '9',
#  423: 'made',
#  424: 'didnt',
#  425: 'dad',
#  426: 'looking',
#  427: 'put',
#  428: 'kiss',
#  429: 'school',
#  430: 'selected',
#  431: 'dis',
#  432: 'po',
#  433: 'plan',
#  434: "there's",
#  435: 'leh',
#  436: 'enough',
#  437: '000',
#  438: 'fun',
#  439: 'little',
#  440: 'maybe',
#  441: 'actually',
#  442: 'probably',
#  443: 'fuck',
#  444: "how's",
#  445: 'princess',
#  446: 'must',
#  447: 'those',
#  448: 'den',
#  449: 'tv',
#  450: 'code',
#  451: 'weekend',
#  452: 'working',
#  453: 'goes',
#  454: 'does',
#  455: 'bus',
#  456: 'until',
#  457: 'award',
#  458: 'speak',
#  459: 'though',
#  460: 'texts',
#  461: 'boy',
#  462: 'while',
#  463: 'collect',
#  464: 'important',
#  465: 'means',
#  466: 'sexy',
#  467: 'show',
#  468: '10p',
#  469: 'times',
#  470: '500',
#  471: 'okay',
#  472: 'plz',
#  473: 'thank',
#  474: 'hav',
#  475: 'worry',
#  476: 'details',
#  477: 'most',
#  478: 'town',
#  479: 'everything',
#  480: 'oso',
#  481: 'true',
#  482: 'pain',
#  483: 'abt',
#  484: 'says',
#  485: 'afternoon',
#  486: 'wif',
#  487: 'wife',
#  488: 'missing',
#  489: 'gift',
#  490: 'bring',
#  491: 'entry',
#  492: 'update',
#  493: 'colour',
#  494: 'm',
#  495: 'saw',
#  496: 'collection',
#  497: 'attempt',
#  498: 'decimal',
#  499: 'makes',
#  500: 'wot',
#  501: 'price',
#  502: 'plus',
#  503: 'lei',
#  504: 'de',
#  505: 'shopping',
#  506: 'juz',
#  507: 'alright',
#  508: 'hair',
#  509: 'making',
#  510: 'messages',
#  511: 'without',
#  512: 'busy',
#  513: 'shop',
#  514: 'asked',
#  515: 'wanted',
#  516: 'wen',
#  517: 'mail',
#  518: 'food',
#  519: 'test',
#  520: 'mob',
#  521: 'feeling',
#  522: 'tones',
#  523: 'havent',
#  524: 'missed',
#  525: 'run',
#  526: 'till',
#  527: 'valid',
#  528: "we're",
#  529: 'came',
#  530: 'else',
#  531: 'join',
#  532: 'hurt',
#  533: 'music',
#  534: 'yourself',
#  535: 'lose',
#  536: 'yours',
#  537: "won't",
#  538: 'games',
#  539: 'together',
#  540: 'id',
#  541: 'net',
#  542: 'til',
#  543: 'since',
#  544: 'wake',
#  545: 'vouchers',
#  546: 'change',
#  547: 'away',
#  548: 'calls',
#  549: 'å£2000',
#  550: 'these',
#  551: 'years',
#  552: 'national',
#  553: 'guy',
#  554: 'haf',
#  555: 'goin',
#  556: 'sae',
#  557: 'story',
#  558: 'double',
#  559: 'both',
#  560: 'beautiful',
#  561: 'noe',
#  562: 'date',
#  563: 'dude',
#  564: 'evening',
#  565: 'words',
#  566: '8',
#  567: 'charge',
#  568: 'nite',
#  569: "what's",
#  570: 'hot',
#  571: '86688',
#  572: 'online',
#  573: 'family',
#  574: 'yesterday',
#  575: 'happen',
#  576: 'driving',
#  577: 'book',
#  578: 'eve',
#  579: 're',
#  580: 'weekly',
#  581: 'answer',
#  582: 'finished',
#  583: 'minute',
#  584: 'calling',
#  585: 'tomo',
#  586: 'bonus',
#  587: 'final',
#  588: 'row',
#  589: 'leaving',
#  590: 'thinking',
#  591: 'news',
#  592: 'wil',
#  593: 'pm',
#  594: "haven't",
#  595: 'full',
#  596: 'started',
#  597: 'å£5000',
#  598: 'order',
#  599: 'comes',
#  600: 'walk',
#  601: 'rite',
#  602: 'believe',
#  603: 'huh',
#  604: 'able',
#  605: 'address',
#  606: 'club',
#  607: 'å£100',
#  608: 'mean',
#  609: "we'll",
#  610: 'game',
#  611: 'wants',
#  612: 'tried',
#  613: 'msgs',
#  614: 'tot',
#  615: 'await',
#  616: 'ring',
#  617: 'hours',
#  618: 'poly',
#  619: 'smiling',
#  620: 'coz',
#  621: 'gr8',
#  622: 'pounds',
#  623: 'forget',
#  624: 'drink',
#  625: 'http',
#  626: 'stay',
#  627: 'sad',
#  628: "''",
#  629: 'smoke',
#  630: 'okie',
#  631: 'taking',
#  632: 'todays',
#  633: 'services',
#  634: 'pics',
#  635: 'question',
#  636: 'top',
#  637: 'aft',
#  638: 'everyone',
#  639: "c's",
#  640: 'cause',
#  641: '750',
#  642: 'delivery',
#  643: 'email',
#  644: 'head',
#  645: '8007',
#  646: 'bored',
#  647: 'break',
#  648: 'loving',
#  649: 'sch',
#  650: 'wid',
#  651: 'set',
#  652: 'college',
#  653: 'land',
#  654: 'awesome',
#  655: 'search',
#  656: 'either',
#  657: 'movie',
#  658: 'saying',
#  659: 'simple',
#  660: 'gd',
#  661: 'old',
#  662: 'kind',
#  663: 'open',
#  664: 'touch',
#  665: 'pic',
#  666: 'each',
#  667: 'private',
#  668: '11',
#  669: 'hard',
#  670: 'choose',
#  671: 'dreams',
#  672: 'needs',
#  673: 'decided',
#  674: 'fast',
#  675: 'boytoy',
#  676: 'close',
#  677: 'oredi',
#  678: 'sleeping',
#  679: 'second',
#  680: 'anytime',
#  681: 'friendship',
#  682: 'drive',
#  683: 'secret',
#  684: '12hrs',
#  685: 'lucky',
#  686: 'parents',
#  687: 'rs',
#  688: 'xx',
#  689: 'type',
#  690: 'winner',
#  691: 'took',
#  692: 'lesson',
#  693: 'tho',
#  694: '100',
#  695: 'dating',
#  696: 'don',
#  697: 'sunday',
#  698: 'å£3',
#  699: 'points',
#  700: 'ltd',
#  701: 'blue',
#  702: 'fancy',
#  703: 'ard',
#  704: 'takes',
#  705: 'hows',
#  706: 'far',
#  707: 'suite342',
#  708: '2lands',
#  709: 'friday',
#  710: 'light',
#  711: 'welcome',
#  712: 'savamob',
#  713: 'pobox',
#  714: 'drop',
#  715: 'freemsg',
#  716: 'hungry',
#  717: 'lets',
#  718: 'unsubscribe',
#  719: 'lots',
#  720: 'neva',
#  721: 'tc',
#  722: 'angry',
#  723: 'company',
#  724: 'fri',
#  725: 'opt',
#  726: 'knw',
#  727: 'å£500',
#  728: 'voucher',
#  729: 'available',
#  730: 'frm',
#  731: 'ha',
#  732: 'girls',
#  733: 'mates',
#  734: 'gone',
#  735: 'pub',
#  736: 'sun',
#  737: 'post',
#  738: 'congratulations',
#  739: 'listen',
#  740: 'sis',
#  741: 'wonderful',
#  742: 'congrats',
#  743: 'yr',
#  744: 'statement',
#  745: 'expires',
#  746: 'read',
#  747: 'whats',
#  748: 'tel',
#  749: 'offers',
#  750: 'hmm',
#  751: 'alone',
#  752: "she's",
#  753: 'darlin',
#  754: 'thinks',
#  755: 'party',
#  756: 'card',
#  757: 'bout',
#  758: 'pretty',
#  759: 'balance',
#  760: 'finally',
#  761: 'happened',
#  762: 'least',
#  763: 'mine',
#  764: 'o',
#  765: 'mah',
#  766: 'happiness',
#  767: 'frnd',
#  768: 'w',
#  769: "you've",
#  770: 'carlos',
#  771: 'anyone',
#  772: 'whatever',
#  773: 'visit',
#  774: 'used',
#  775: 'worth',
#  776: 'content',
#  777: 'frnds',
#  778: 'sea',
#  779: 'meant',
#  780: 'found',
#  781: '0800',
#  782: 'ten',
#  783: 'trip',
#  784: 'hit',
#  785: 'identifier',
#  786: 'ago',
#  787: 'fucking',
#  788: 'å£2',
#  789: '03',
#  790: 'uncle',
#  791: 'area',
#  792: 'mr',
#  793: 'tired',
#  794: 'ass',
#  795: 'weeks',
#  796: 'sounds',
#  797: 'correct',
#  798: 'crazy',
#  799: 'txts',
#  800: 'fone',
#  801: 'operator',
#  802: 'lovely',
#  803: 'within',
#  804: 'smth',
#  805: 'wrong',
#  806: '08000930705',
#  807: 'fr',
#  808: 'log',
#  809: 'mrng',
#  810: 'their',
#  811: 'india',
#  812: 'direct',
#  813: 'bank',
#  814: 'reveal',
#  815: 'info',
#  816: 'course',
#  817: 'luck',
#  818: 'brother',
#  819: 'reason',
#  820: "'",
#  821: '30',
#  822: '\x89û',
#  823: 'chikku',
#  824: 'b4',
#  825: 'surprise',
#  826: 'gal',
#  827: 'saturday',
#  828: 'treat',
#  829: 'currently',
#  830: "you'll",
#  831: 'nt',
#  832: 'phones',
#  833: 'knew',
#  834: 'bslvyl',
#  835: 'point',
#  836: 'wit',
#  837: 'sister',
#  838: 'whole',
#  839: 'å£250',
#  840: 'unlimited',
#  841: '08000839402',
#  842: 'song',
#  843: 'questions',
#  844: 'ni8',
#  845: 'credit',
#  846: 'caller',
#  847: 'asap',
#  848: 'ex',
#  849: 'wkly',
#  850: 'std',
#  851: 'mobileupd8',
#  852: 'lost',
#  853: 'mum',
#  854: 'sound',
#  855: 'swing',
#  856: 'camcorder',
#  857: 'download',
#  858: 'goodmorning',
#  859: 'cum',
#  860: 'semester',
#  861: 'invited',
#  862: 'hee',
#  863: 'seeing',
#  864: 'christmas',
#  865: 'age',
#  866: 'hand',
#  867: 'mate',
#  868: 'earlier',
#  869: 'hold',
#  870: 'felt',
#  871: 'information',
#  872: 'quiz',
#  873: 'dogging',
#  874: 'sex',
#  875: 'nyt',
#  876: 'hmmm',
#  877: 'park',
#  878: 'prob',
#  879: 'valued',
#  880: 'eg',
#  881: 'seen',
#  882: 'ugh',
#  883: 'bcoz',
#  884: 'nope',
#  885: 'difficult',
#  886: 'project',
#  887: 'father',
#  888: 'ans',
#  889: 'comp',
#  890: 'match',
#  891: 'mobiles',
#  892: 'asking',
#  893: 'sending',
#  894: 'complimentary',
#  895: '2003',
#  896: 'un',
#  897: 'almost',
#  898: 'na',
#  899: 'terms',
#  900: 'wow',
#  901: 'wonder',
#  902: 'muz',
#  903: 'mu',
#  904: 'figure',
#  905: 'gas',
#  906: 'supposed',
#  907: 'pete',
#  908: 'motorola',
#  909: 'call2optout',
#  910: 'wine',
#  911: 'auction',
#  912: 'hg',
#  913: 'laptop',
#  914: 'slow',
#  915: 'mom',
#  916: 'woke',
#  917: 'case',
#  918: 'å£350',
#  919: 'through',
#  920: "isn't",
#  921: 'red',
#  922: 'booked',
#  923: 'save',
#  924: 'loved',
#  925: 'usf',
#  926: 'doin',
#  927: 'rental',
#  928: '20',
#  929: 'shower',
#  930: 'gym',
#  931: 'askd',
#  932: 'orchard',
#  933: 'admirer',
#  934: 'ends',
#  935: 'hmv',
#  936: 'loads',
#  937: 'checking',
#  938: "i'd",
#  939: 'w1j6hl',
#  940: 'press',
#  941: 'support',
#  942: 'outside',
#  943: 'bill',
#  944: 'charged',
#  945: 'die',
#  946: 'mayb',
#  947: 'stupid',
#  948: 'drugs',
#  949: 'wishing',
#  950: 'entered',
#  951: 'confirm',
#  952: 'yar',
#  953: 'glad',
#  954: 'sort',
#  955: 'bathe',
#  956: 'pass',
#  957: 'wana',
#  958: 'dream',
#  959: 'discount',
#  960: '00',
#  961: 'kids',
#  962: 'abiola',
#  963: 'couple',
#  964: 'side',
#  965: '87066',
#  966: 'cut',
#  967: 'gets',
#  968: 'fact',
#  969: 'rply',
#  970: 'small',
#  971: 'eh',
#  972: 'slowly',
#  973: 'crave',
#  974: 'understand',
#  975: 'grins',
#  976: 'talking',
#  977: 'telling',
#  978: 'snow',
#  979: 'gettin',
#  980: 'myself',
#  981: 'via',
#  982: 'met',
#  983: 'sell',
#  984: 'enter',
#  985: 'numbers',
#  986: 'st',
#  987: 'ringtones',
#  988: '800',
#  989: 'redeemed',
#  990: '04',
#  991: 'cheap',
#  992: 'laugh',
#  993: 'thinkin',
#  994: 'rain',
#  995: 'others',
#  996: 'study',
#  997: 'del',
#  998: '150',
#  999: 'jay',
#  1000: 'weed',
#  ...}

# %% [markdown]
# **Creating model and Adding the layers**

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# **Compile the model**

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           259872
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 315,113
# Trainable params: 315,113
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Fit the model**

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 19s 532ms/step - loss: 0.4951 - accuracy: 0.8458 - val_loss: 0.3417 - val_accuracy: 0.8713
# Epoch 2/10
# 30/30 [==============================] - 13s 423ms/step - loss: 0.2481 - accuracy: 0.9168 - val_loss: 0.1085 - val_accuracy: 0.9821

# %% [markdown]
# **Save the model**

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# **Test the model**

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 40ms/step - loss: 0.1385 - accuracy: 0.9737

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.138
#   Accuracy: 0.974
