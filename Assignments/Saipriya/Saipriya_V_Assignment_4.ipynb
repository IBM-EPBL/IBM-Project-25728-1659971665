# %% [markdown]
# **Importing** **the** **libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# **Reading** **the** **dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# **Process the data**

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ..., 466,  71,  79],
#        [  0,   0,   0, ...,  18,   5, 137],
#        [  0,   0,   0, ...,  40, 793, 793],
#        ...,
#        [  0,   0,   0, ...,  29, 329,  44],
#        [  0,   0,   0, ...,  20,  66, 382],
#        [  0,   0,   0, ...,  39,  95,  17]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: 'that',
#  20: 'now',
#  21: '2',
#  22: 'are',
#  23: 'so',
#  24: 'but',
#  25: 'not',
#  26: 'or',
#  27: 'do',
#  28: 'can',
#  29: 'ur',
#  30: 'get',
#  31: 'at',
#  32: 'will',
#  33: "i'm",
#  34: 'if',
#  35: 'with',
#  36: 'be',
#  37: 'no',
#  38: 'just',
#  39: 'we',
#  40: 'this',
#  41: 'lt',
#  42: 'gt',
#  43: 'up',
#  44: '4',
#  45: 'when',
#  46: 'ok',
#  47: 'from',
#  48: 'go',
#  49: 'how',
#  50: 'out',
#  51: 'free',
#  52: 'all',
#  53: 'what',
#  54: 'know',
#  55: 'like',
#  56: 'was',
#  57: 'got',
#  58: 'its',
#  59: 'then',
#  60: 'good',
#  61: 'am',
#  62: 'come',
#  63: 'time',
#  64: 'only',
#  65: 'day',
#  66: 'love',
#  67: 'there',
#  68: 'send',
#  69: 'as',
#  70: 'text',
#  71: 'going',
#  72: 'he',
#  73: 'want',
#  74: 'by',
#  75: 'need',
#  76: 'one',
#  77: 'txt',
#  78: 'r',
#  79: 'home',
#  80: 'about',
#  81: "i'll",
#  82: 'sorry',
#  83: 'back',
#  84: 'lor',
#  85: 'da',
#  86: 'k',
#  87: 'n',
#  88: 'see',
#  89: 'today',
#  90: 'our',
#  91: 'she',
#  92: 'stop',
#  93: 'still',
#  94: 'hi',
#  95: 'dont',
#  96: 'tell',
#  97: 'mobile',
#  98: 'take',
#  99: "don't",
#  100: 'reply',
#  101: 'her',
#  102: 'any',
#  103: 'please',
#  104: 'new',
#  105: 'later',
#  106: 'been',
#  107: 'think',
#  108: 'pls',
#  109: 'd',
#  110: 'dear',
#  111: 'here',
#  112: 'oh',
#  113: 'phone',
#  114: 'some',
#  115: 'ì',
#  116: 'week',
#  117: 'much',
#  118: 'they',
#  119: 'hey',
#  120: 'night',
#  121: 'him',
#  122: 'well',
#  123: 'happy',
#  124: 'great',
#  125: 'has',
#  126: 'claim',
#  127: 'hope',
#  128: 'too',
#  129: 'more',
#  130: 'who',
#  131: 'did',
#  132: 'msg',
#  133: '1',
#  134: 'an',
#  135: 'yes',
#  136: 'make',
#  137: 'way',
#  138: 'work',
#  139: 'had',
#  140: 'where',
#  141: 'should',
#  142: 'prize',
#  143: "it's",
#  144: 'give',
#  145: 'c',
#  146: 'www',
#  147: 'tomorrow',
#  148: 'number',
#  149: 'say',
#  150: 'really',
#  151: 'already',
#  152: 'wat',
#  153: 'message',
#  154: 'after',
#  155: 'said',
#  156: 'amp',
#  157: 'yeah',
#  158: 'right',
#  159: 'cash',
#  160: 'doing',
#  161: 'life',
#  162: '3',
#  163: 'e',
#  164: 'find',
#  165: 'im',
#  166: 'them',
#  167: 'ask',
#  168: 'cos',
#  169: 'why',
#  170: 'very',
#  171: 'meet',
#  172: 'won',
#  173: 'babe',
#  174: 'last',
#  175: 'thanks',
#  176: 'anything',
#  177: 'also',
#  178: 't',
#  179: 'b',
#  180: 'com',
#  181: 'let',
#  182: 'urgent',
#  183: 'lol',
#  184: 'something',
#  185: 'win',
#  186: 'nokia',
#  187: 'care',
#  188: 'every',
#  189: 'would',
#  190: 'sent',
#  191: 'buy',
#  192: 'contact',
#  193: 'pick',
#  194: 'even',
#  195: 'before',
#  196: '150p',
#  197: 'keep',
#  198: 'miss',
#  199: 'morning',
#  200: 'min',
#  201: 'thing',
#  202: 'were',
#  203: 'sure',
#  204: 'us',
#  205: 'uk',
#  206: 'first',
#  207: 'ya',
#  208: 'cant',
#  209: 's',
#  210: 'over',
#  211: 'place',
#  212: 'again',
#  213: 'tone',
#  214: 'feel',
#  215: 'nice',
#  216: 'someone',
#  217: "i've",
#  218: 'went',
#  219: 'many',
#  220: 'next',
#  221: 'tonight',
#  222: '50',
#  223: 'x',
#  224: 'wait',
#  225: 'which',
#  226: '5',
#  227: 'money',
#  228: 'soon',
#  229: 'his',
#  230: "can't",
#  231: 'off',
#  232: 'customer',
#  233: 'sleep',
#  234: 'could',
#  235: 'sms',
#  236: "that's",
#  237: 'gonna',
#  238: 'gud',
#  239: 'friends',
#  240: 'dun',
#  241: 'late',
#  242: '16',
#  243: 'told',
#  244: 'leave',
#  245: 'wish',
#  246: 'help',
#  247: 'done',
#  248: 'things',
#  249: 'guaranteed',
#  250: 'chat',
#  251: 'down',
#  252: 'around',
#  253: 'always',
#  254: 'other',
#  255: 'co',
#  256: 'service',
#  257: 'coming',
#  258: 'use',
#  259: 'yet',
#  260: 'hello',
#  261: 'haha',
#  262: 'ìï',
#  263: 'same',
#  264: 'thk',
#  265: 'mins',
#  266: 'thought',
#  267: 'draw',
#  268: 'fine',
#  269: '18',
#  270: 'people',
#  271: 'year',
#  272: 'per',
#  273: 'lunch',
#  274: "didn't",
#  275: 'heart',
#  276: 'v',
#  277: 'special',
#  278: 'holiday',
#  279: 'wan',
#  280: '6',
#  281: 'friend',
#  282: 'man',
#  283: 'smile',
#  284: 'name',
#  285: 'y',
#  286: 'try',
#  287: "you're",
#  288: 'may',
#  289: 'best',
#  290: 'cs',
#  291: 'class',
#  292: 'line',
#  293: 'few',
#  294: 'trying',
#  295: 'ready',
#  296: 'stuff',
#  297: 'getting',
#  298: 'mind',
#  299: 'meeting',
#  300: 'days',
#  301: 'yup',
#  302: 'house',
#  303: 'talk',
#  304: 'better',
#  305: 'å£1',
#  306: 'bit',
#  307: 'yo',
#  308: 'than',
#  309: 'waiting',
#  310: 'never',
#  311: 'thats',
#  312: 'finish',
#  313: 'half',
#  314: 'god',
#  315: 'check',
#  316: 'being',
#  317: '7',
#  318: 'because',
#  319: 'long',
#  320: 'problem',
#  321: 'car',
#  322: 'cool',
#  323: 'end',
#  324: 'dat',
#  325: 'job',
#  326: 'eat',
#  327: 'birthday',
#  328: 'lar',
#  329: 'luv',
#  330: 'play',
#  331: 'live',
#  332: 'latest',
#  333: 'person',
#  334: 'account',
#  335: 'having',
#  336: 'ill',
#  337: 'camera',
#  338: 'world',
#  339: 'wk',
#  340: 'chance',
#  341: '1st',
#  342: 'enjoy',
#  343: 'into',
#  344: 'guess',
#  345: 'shows',
#  346: 'awarded',
#  347: 'lot',
#  348: 'sir',
#  349: 'shit',
#  350: 'å£1000',
#  351: 'forgot',
#  352: 'jus',
#  353: 'dinner',
#  354: 'real',
#  355: 'nothing',
#  356: 'ah',
#  357: 'maybe',
#  358: 'month',
#  359: 'guys',
#  360: 'offer',
#  361: 'wanna',
#  362: 'watch',
#  363: 'face',
#  364: 'bed',
#  365: 'bt',
#  366: '150ppm',
#  367: 'thanx',
#  368: 'tv',
#  369: 'bad',
#  370: 'called',
#  371: 'probably',
#  372: 'sat',
#  373: 'wont',
#  374: 'liao',
#  375: 'room',
#  376: 'does',
#  377: 'landline',
#  378: 'cost',
#  379: 'another',
#  380: 'look',
#  381: 'word',
#  382: 'xxx',
#  383: 'sweet',
#  384: 'leh',
#  385: 'early',
#  386: 'video',
#  387: 'quite',
#  388: 'hear',
#  389: 'princess',
#  390: 'girl',
#  391: 'speak',
#  392: 'might',
#  393: 'plan',
#  394: 'box',
#  395: 'll',
#  396: 'ever',
#  397: 'didnt',
#  398: 'watching',
#  399: 'start',
#  400: '10',
#  401: 'pa',
#  402: 'once',
#  403: '2nd',
#  404: 'boy',
#  405: 'aight',
#  406: 'big',
#  407: 'easy',
#  408: 'details',
#  409: 'minutes',
#  410: 'reach',
#  411: 'pay',
#  412: 'office',
#  413: 'remember',
#  414: 'baby',
#  415: 'part',
#  416: 'orange',
#  417: 'two',
#  418: 'between',
#  419: 'enough',
#  420: 'left',
#  421: 'wife',
#  422: 'thank',
#  423: "he's",
#  424: 'hour',
#  425: 'dis',
#  426: '9',
#  427: 'rate',
#  428: 'abt',
#  429: 'ringtone',
#  430: 'put',
#  431: 'came',
#  432: 'actually',
#  433: 'true',
#  434: 'weekend',
#  435: 'po',
#  436: 'den',
#  437: 'looking',
#  438: "there's",
#  439: 'those',
#  440: 'town',
#  441: 'kiss',
#  442: 'fun',
#  443: 'm',
#  444: 'code',
#  445: '000',
#  446: 'dad',
#  447: 'made',
#  448: 'shopping',
#  449: 'network',
#  450: 'decimal',
#  451: 'fuck',
#  452: 'apply',
#  453: 'means',
#  454: 'dunno',
#  455: 'mob',
#  456: 'collection',
#  457: 'wif',
#  458: 'plz',
#  459: 'receive',
#  460: 'little',
#  461: 'asked',
#  462: 'tmr',
#  463: 'mail',
#  464: 'texts',
#  465: 'afternoon',
#  466: 'bus',
#  467: 'shall',
#  468: 'anyway',
#  469: 'till',
#  470: 'gift',
#  471: 'update',
#  472: 'years',
#  473: 'sexy',
#  474: 'havent',
#  475: 'wot',
#  476: 'missed',
#  477: 'must',
#  478: 'everything',
#  479: 'though',
#  480: 'wanted',
#  481: 'important',
#  482: "how's",
#  483: 'until',
#  484: 'most',
#  485: 'dude',
#  486: 'away',
#  487: 'hair',
#  488: 'okay',
#  489: 'id',
#  490: 'worry',
#  491: 'shop',
#  492: 'guy',
#  493: 'messages',
#  494: 'words',
#  495: 'while',
#  496: '8',
#  497: 'valid',
#  498: 'tones',
#  499: 'says',
#  500: 'calls',
#  501: 'hav',
#  502: 'book',
#  503: 'alright',
#  504: 'beautiful',
#  505: 'attempt',
#  506: 'school',
#  507: 'show',
#  508: 'missing',
#  509: 'pain',
#  510: 'award',
#  511: 'colour',
#  512: 'plus',
#  513: 'wake',
#  514: 'family',
#  515: 'collect',
#  516: 'music',
#  517: 'trip',
#  518: 'lei',
#  519: "''",
#  520: '10p',
#  521: 'without',
#  522: 'comes',
#  523: 'top',
#  524: 'g',
#  525: 'nite',
#  526: 'å£5000',
#  527: 'since',
#  528: 'busy',
#  529: 'sch',
#  530: 'else',
#  531: 'å£100',
#  532: 'selected',
#  533: 'wen',
#  534: '500',
#  535: 'answer',
#  536: 're',
#  537: "we're",
#  538: 'ring',
#  539: 'test',
#  540: 'evening',
#  541: 'goin',
#  542: 'de',
#  543: 'entry',
#  544: 'tried',
#  545: 'drive',
#  546: 'oso',
#  547: 'working',
#  548: 'eve',
#  549: 'sae',
#  550: 'xmas',
#  551: 'full',
#  552: 'online',
#  553: 'bored',
#  554: 'makes',
#  555: 'delivery',
#  556: 'address',
#  557: 'yesterday',
#  558: "won't",
#  559: "haven't",
#  560: 'change',
#  561: 'price',
#  562: 'goes',
#  563: 'vouchers',
#  564: 'question',
#  565: 'chikku',
#  566: 'haf',
#  567: 'okie',
#  568: 'food',
#  569: 'both',
#  570: 'wid',
#  571: 'hours',
#  572: 'join',
#  573: 'mean',
#  574: 'times',
#  575: 'sad',
#  576: 'friendship',
#  577: 'await',
#  578: 'double',
#  579: 'hurt',
#  580: 'charge',
#  581: 'bring',
#  582: 'either',
#  583: 'set',
#  584: 'angry',
#  585: 'saw',
#  586: 'old',
#  587: 'wants',
#  588: 'http',
#  589: 'driving',
#  590: 'ard',
#  591: 'making',
#  592: 'juz',
#  593: 'weekly',
#  594: 'calling',
#  595: 'news',
#  596: 'bonus',
#  597: '8007',
#  598: 'row',
#  599: 'took',
#  600: 'tot',
#  601: 'leaving',
#  602: 'net',
#  603: 'minute',
#  604: 'able',
#  605: 'run',
#  606: 'yours',
#  607: 'dreams',
#  608: 'rite',
#  609: 'whats',
#  610: 'cause',
#  611: 'walk',
#  612: 'stay',
#  613: 'yourself',
#  614: 'card',
#  615: 'saying',
#  616: 'finished',
#  617: 'å£2000',
#  618: 'coz',
#  619: 'club',
#  620: 'points',
#  621: 'pub',
#  622: 'search',
#  623: 'drink',
#  624: 'neva',
#  625: 'sleeping',
#  626: 'wil',
#  627: 'these',
#  628: 'game',
#  629: 'lets',
#  630: 'national',
#  631: 'noe',
#  632: 'awesome',
#  633: 'everyone',
#  634: 'auction',
#  635: 'thinking',
#  636: 'pounds',
#  637: 'pm',
#  638: 'order',
#  639: 'pic',
#  640: 'gd',
#  641: 'brother',
#  642: 'å£500',
#  643: 'drop',
#  644: 'together',
#  645: 'loving',
#  646: '86688',
#  647: 'info',
#  648: "we'll",
#  649: 'date',
#  650: 'smiling',
#  651: 'gr8',
#  652: 'lesson',
#  653: 'todays',
#  654: 'land',
#  655: 'feeling',
#  656: "what's",
#  657: 'movie',
#  658: 'choose',
#  659: 'games',
#  660: 'lose',
#  661: 'break',
#  662: 'hot',
#  663: 'ha',
#  664: 'til',
#  665: 'alone',
#  666: 'post',
#  667: 'whatever',
#  668: 'started',
#  669: 'mum',
#  670: 'happen',
#  671: 'services',
#  672: 'voucher',
#  673: 'tomo',
#  674: 'xx',
#  675: 'huh',
#  676: 'believe',
#  677: 'lots',
#  678: 'pics',
#  679: 'finally',
#  680: 'rs',
#  681: 'each',
#  682: 'close',
#  683: 'don',
#  684: 'available',
#  685: 'congrats',
#  686: "c's",
#  687: 'head',
#  688: 'private',
#  689: '12hrs',
#  690: 'gone',
#  691: '100',
#  692: "she's",
#  693: 'anyone',
#  694: 'darlin',
#  695: 'type',
#  696: 'smoke',
#  697: 'worth',
#  698: 'lucky',
#  699: 'fri',
#  700: 'chennai',
#  701: 'treat',
#  702: 'carlos',
#  703: 'sister',
#  704: 'saturday',
#  705: 'course',
#  706: '\x89û',
#  707: 'company',
#  708: 'final',
#  709: 'expires',
#  710: 'msgs',
#  711: 'o',
#  712: 'suite342',
#  713: '2lands',
#  714: 'taking',
#  715: 'smth',
#  716: 'wit',
#  717: 'tho',
#  718: 'open',
#  719: 'read',
#  720: 'earlier',
#  721: 'congratulations',
#  722: 'opt',
#  723: 'hand',
#  724: '750',
#  725: 'prob',
#  726: 'bout',
#  727: 'oredi',
#  728: 'tel',
#  729: 'hit',
#  730: 'sea',
#  731: 'second',
#  732: 'knw',
#  733: 'blue',
#  734: 'college',
#  735: 'ltd',
#  736: 'hungry',
#  737: 'girls',
#  738: 'simple',
#  739: 'quiz',
#  740: 'savamob',
#  741: 'aft',
#  742: 'decided',
#  743: 'anytime',
#  744: 'takes',
#  745: 'fucking',
#  746: 'touch',
#  747: 'mine',
#  748: 'sun',
#  749: 'far',
#  750: 'story',
#  751: 'player',
#  752: 'needs',
#  753: 'lovely',
#  754: 'outside',
#  755: 'ago',
#  756: 'sounds',
#  757: 'hold',
#  758: 'goodmorning',
#  759: 'winner',
#  760: 'mayb',
#  761: 'statement',
#  762: 'identifier',
#  763: 'wkly',
#  764: 'used',
#  765: 'seeing',
#  766: 'w',
#  767: 'download',
#  768: 'frnd',
#  769: 'content',
#  770: 'wonderful',
#  771: '30',
#  772: 'unsubscribe',
#  773: 'visit',
#  774: 'poly',
#  775: 'mates',
#  776: 'pobox',
#  777: 'fast',
#  778: 'whole',
#  779: 'case',
#  780: "doesn't",
#  781: 'frm',
#  782: 'hows',
#  783: 'mobileupd8',
#  784: 'offers',
#  785: 'kind',
#  786: 'felt',
#  787: 'almost',
#  788: '08000930705',
#  789: 'å£2',
#  790: 'ni8',
#  791: 'log',
#  792: "'",
#  793: 'christmas',
#  794: 'weeks',
#  795: 'meant',
#  796: 'parents',
#  797: 'their',
#  798: 'least',
#  799: 'difficult',
#  800: 'wrong',
#  801: 'frnds',
#  802: 'secret',
#  803: 'correct',
#  804: 'happened',
#  805: 'fr',
#  806: 'snow',
#  807: 'forget',
#  808: 'stupid',
#  809: 'mom',
#  810: 'email',
#  811: 'enter',
#  812: 'å£250',
#  813: 'yr',
#  814: 'fone',
#  815: 'friday',
#  816: 'gotta',
#  817: 'valued',
#  818: 'mate',
#  819: 'project',
#  820: 'india',
#  821: "you've",
#  822: 'hard',
#  823: 'found',
#  824: 'party',
#  825: 'å£3',
#  826: 'gal',
#  827: 'crazy',
#  828: '11',
#  829: 'f',
#  830: 'nope',
#  831: 'caller',
#  832: '08000839402',
#  833: 'dating',
#  834: 'tc',
#  835: 'camcorder',
#  836: '03',
#  837: 'happiness',
#  838: 'within',
#  839: 'surprise',
#  840: 'press',
#  841: 'cut',
#  842: 'exam',
#  843: 'father',
#  844: 'b4',
#  845: 'truth',
#  846: 'mr',
#  847: 'thinks',
#  848: 'telling',
#  849: 'jay',
#  850: 'cum',
#  851: 'ugh',
#  852: 'darren',
#  853: 'gn',
#  854: 'march',
#  855: 'kate',
#  856: 'operator',
#  857: 'mu',
#  858: 'clean',
#  859: 'ten',
#  860: 'uncle',
#  861: 'credit',
#  862: 'na',
#  863: 'light',
#  864: 'understand',
#  865: 'balance',
#  866: 'lost',
#  867: 'nt',
#  868: '2003',
#  869: '800',
#  870: 'un',
#  871: 'bcoz',
#  872: 'bslvyl',
#  873: 'discount',
#  874: 'information',
#  875: 'reading',
#  876: '87066',
#  877: 'ans',
#  878: 'freemsg',
#  879: 'askd',
#  880: 'knew',
#  881: 'st',
#  882: 'song',
#  883: 'ends',
#  884: 'phones',
#  885: 'hmmm',
#  886: 'bank',
#  887: 'hee',
#  888: 'invited',
#  889: 'picking',
#  890: 'gas',
#  891: 'point',
#  892: 'heard',
#  893: 'wow',
#  894: 'rental',
#  895: 'slow',
#  896: 'motorola',
#  897: 'through',
#  898: "wasn't",
#  899: 'listen',
#  900: "you'll",
#  901: 'asking',
#  902: 'sis',
#  903: 'luck',
#  904: 'voice',
#  905: 'loved',
#  906: 'study',
#  907: 'txts',
#  908: 'terms',
#  909: 'wonder',
#  910: 'semester',
#  911: 'computer',
#  912: 'figure',
#  913: 'couple',
#  914: 'sell',
#  915: 'hmv',
#  916: 'questions',
#  917: '04',
#  918: 'gym',
#  919: 'tired',
#  920: 'hg',
#  921: 'w1j6hl',
#  922: 'dnt',
#  923: 'store',
#  924: 'feels',
#  925: '0800',
#  926: 'mm',
#  927: 'met',
#  928: 'currently',
#  929: 'mrng',
#  930: 'redeemed',
#  931: 'comp',
#  932: 'fancy',
#  933: 'safe',
#  934: 'shower',
#  935: 'grins',
#  936: 'sound',
#  937: 'complimentary',
#  938: 'bath',
#  939: 'txting',
#  940: 'move',
#  941: 'pass',
#  942: 'ipod',
#  943: 'std',
#  944: 'laptop',
#  945: 'hmm',
#  946: 'supposed',
#  947: 'pretty',
#  948: 'sunday',
#  949: 'woke',
#  950: 'ac',
#  951: 'sending',
#  952: 'il',
#  953: 'call2optout',
#  954: 'john',
#  955: 'whenever',
#  956: 'sort',
#  957: 'monday',
#  958: 'remove',
#  959: 'dream',
#  960: '20',
#  961: '12',
#  962: '00',
#  963: 'rakhesh',
#  964: 'p',
#  965: 'police',
#  966: 'reason',
#  967: 'less',
#  968: 'rply',
#  969: 'tonite',
#  970: 'worried',
#  971: 'pete',
#  972: 'etc',
#  973: 'possible',
#  974: 'representative',
#  975: 'immediately',
#  976: 'bill',
#  977: 'drugs',
#  978: 'charged',
#  979: 'gets',
#  980: 'small',
#  981: 'energy',
#  982: 'knows',
#  983: 'yar',
#  984: 'park',
#  985: 'dead',
#  986: 'ge',
#  987: 'water',
#  988: 'swing',
#  989: 'write',
#  990: 'th',
#  991: 'welcome',
#  992: 'children',
#  993: 'link',
#  994: 'doin',
#  995: 'slowly',
#  996: 'blood',
#  997: 'pray',
#  998: 'age16',
#  999: 'against',
#  1000: 'area',
#  ...}

# %% [markdown]
# **Creating model and Adding the layers**

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# **Compile the model**

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           263392
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 318,633
# Trainable params: 318,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Fit the model**

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 14s 373ms/step - loss: 0.5047 - accuracy: 0.8477 - val_loss: 0.3511 - val_accuracy: 0.8713
# Epoch 2/10
# 30/30 [==============================] - 11s 351ms/step - loss: 0.2562 - accuracy: 0.9163 - val_loss: 0.1376 - val_accuracy: 0.9768

# %% [markdown]
# **Save the model**

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# **Test the model**

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1439 - accuracy: 0.9761

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.144
#   Accuracy: 0.976
