# %% [markdown]
# **Importing** **the** **libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# **Reading** **the** **dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# **Process the data**

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,  98,  69, 111],
#        [  0,   0,   0, ..., 272, 974,  10],
#        [  0,   0,   0, ..., 213,  16,  21],
#        ...,
#        [  0,   0,   0, ...,  32,  68, 321],
#        [  0,   0,   0, ...,   9,  97, 981],
#        [  0,   0,   0, ..., 410, 878,  67]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: 'are',
#  20: '2',
#  21: 'now',
#  22: 'that',
#  23: 'so',
#  24: 'but',
#  25: 'not',
#  26: 'do',
#  27: 'or',
#  28: 'can',
#  29: 'at',
#  30: "i'm",
#  31: 'with',
#  32: 'get',
#  33: 'will',
#  34: 'be',
#  35: 'ur',
#  36: 'just',
#  37: 'if',
#  38: 'no',
#  39: 'this',
#  40: 'we',
#  41: 'gt',
#  42: 'lt',
#  43: '4',
#  44: 'up',
#  45: 'when',
#  46: 'from',
#  47: 'ok',
#  48: 'how',
#  49: 'all',
#  50: 'free',
#  51: 'out',
#  52: 'go',
#  53: 'what',
#  54: 'know',
#  55: 'good',
#  56: 'then',
#  57: 'got',
#  58: 'like',
#  59: 'its',
#  60: 'come',
#  61: 'time',
#  62: 'day',
#  63: 'was',
#  64: 'love',
#  65: 'only',
#  66: 'am',
#  67: 'text',
#  68: 'there',
#  69: 'he',
#  70: 'send',
#  71: 'as',
#  72: 'want',
#  73: 'going',
#  74: 'txt',
#  75: 'need',
#  76: 'one',
#  77: 'about',
#  78: "i'll",
#  79: 'by',
#  80: 'sorry',
#  81: 'r',
#  82: 'see',
#  83: 'stop',
#  84: 'lor',
#  85: 'home',
#  86: 'today',
#  87: 'still',
#  88: 'k',
#  89: 'reply',
#  90: 'hi',
#  91: 'back',
#  92: 'n',
#  93: 'dont',
#  94: 'new',
#  95: 'mobile',
#  96: 'her',
#  97: 'da',
#  98: 'think',
#  99: 'she',
#  100: 'take',
#  101: 'please',
#  102: 'our',
#  103: 'later',
#  104: 'dear',
#  105: "don't",
#  106: 'pls',
#  107: 'been',
#  108: 'they',
#  109: 'any',
#  110: 'well',
#  111: 'has',
#  112: 'night',
#  113: 'here',
#  114: 'ì',
#  115: 'd',
#  116: 'did',
#  117: 'phone',
#  118: 'much',
#  119: 'tell',
#  120: '1',
#  121: 'week',
#  122: 'some',
#  123: 'where',
#  124: 'an',
#  125: 'hope',
#  126: 'claim',
#  127: 'msg',
#  128: 'who',
#  129: 'hey',
#  130: 'oh',
#  131: 'too',
#  132: 'way',
#  133: 'more',
#  134: 'great',
#  135: 'yes',
#  136: 'him',
#  137: 'work',
#  138: 'make',
#  139: 'had',
#  140: 'c',
#  141: 'www',
#  142: 'give',
#  143: 'number',
#  144: 'tomorrow',
#  145: 'happy',
#  146: 'already',
#  147: 'right',
#  148: 'doing',
#  149: "it's",
#  150: 'wat',
#  151: '3',
#  152: 'should',
#  153: 'yeah',
#  154: 'say',
#  155: 'prize',
#  156: 'e',
#  157: 'said',
#  158: 'im',
#  159: 'after',
#  160: 'cash',
#  161: 'message',
#  162: 'really',
#  163: 'ask',
#  164: 'morning',
#  165: 'life',
#  166: 'them',
#  167: 'amp',
#  168: 'last',
#  169: 'meet',
#  170: 'win',
#  171: 'babe',
#  172: 'find',
#  173: 'very',
#  174: 'miss',
#  175: 'why',
#  176: 'sure',
#  177: 't',
#  178: 'every',
#  179: 'would',
#  180: 'care',
#  181: 'thanks',
#  182: 'cos',
#  183: 'again',
#  184: 'also',
#  185: 'sent',
#  186: 'won',
#  187: 'min',
#  188: 'nokia',
#  189: 'soon',
#  190: 'lol',
#  191: 'pick',
#  192: 'let',
#  193: 'uk',
#  194: 'com',
#  195: 'contact',
#  196: 'over',
#  197: '150p',
#  198: 'cant',
#  199: '50',
#  200: 'urgent',
#  201: 'before',
#  202: 'first',
#  203: 'wait',
#  204: 'anything',
#  205: 'sleep',
#  206: 'b',
#  207: 's',
#  208: 'thing',
#  209: 'us',
#  210: 'gud',
#  211: 'something',
#  212: '5',
#  213: 'service',
#  214: 'place',
#  215: 'went',
#  216: 'feel',
#  217: 'even',
#  218: 'nice',
#  219: 'next',
#  220: 'his',
#  221: 'tone',
#  222: "can't",
#  223: 'per',
#  224: 'friends',
#  225: 'late',
#  226: 'around',
#  227: 'always',
#  228: 'buy',
#  229: 'which',
#  230: 'customer',
#  231: 'ya',
#  232: 'keep',
#  233: 'hello',
#  234: 'money',
#  235: "i've",
#  236: 'could',
#  237: 'co',
#  238: 'off',
#  239: 'were',
#  240: 'many',
#  241: 'fine',
#  242: 'x',
#  243: 'tonight',
#  244: 'v',
#  245: "you're",
#  246: 'chat',
#  247: 'done',
#  248: 'wish',
#  249: 'things',
#  250: 'down',
#  251: 'someone',
#  252: 'getting',
#  253: 'coming',
#  254: 'special',
#  255: 'name',
#  256: '16',
#  257: 'wan',
#  258: 'sms',
#  259: 'other',
#  260: 'people',
#  261: 'leave',
#  262: 'dun',
#  263: 'mins',
#  264: 'year',
#  265: 'live',
#  266: 'help',
#  267: 'ìï',
#  268: 'told',
#  269: '6',
#  270: 'haha',
#  271: 'same',
#  272: 'best',
#  273: "that's",
#  274: '7',
#  275: 'gonna',
#  276: 'holiday',
#  277: 'friend',
#  278: 'may',
#  279: 'waiting',
#  280: 'man',
#  281: '18',
#  282: 'yet',
#  283: 'thought',
#  284: 'guaranteed',
#  285: "didn't",
#  286: 'smile',
#  287: 'class',
#  288: 'house',
#  289: 'few',
#  290: 'talk',
#  291: 'heart',
#  292: 'try',
#  293: 'better',
#  294: 'thats',
#  295: 'being',
#  296: 'ready',
#  297: 'cs',
#  298: 'receive',
#  299: 'ill',
#  300: 'thk',
#  301: 'draw',
#  302: 'job',
#  303: 'trying',
#  304: 'person',
#  305: 'y',
#  306: 'account',
#  307: 'having',
#  308: 'line',
#  309: 'use',
#  310: 'real',
#  311: 'long',
#  312: 'å£1',
#  313: 'stuff',
#  314: 'check',
#  315: 'enjoy',
#  316: 'chance',
#  317: 'sir',
#  318: 'yo',
#  319: 'lot',
#  320: 'cool',
#  321: 'lar',
#  322: 'play',
#  323: 'mind',
#  324: 'half',
#  325: 'god',
#  326: 'end',
#  327: 'lunch',
#  328: 'eat',
#  329: 'never',
#  330: 'than',
#  331: 'finish',
#  332: 'yup',
#  333: 'meeting',
#  334: '1st',
#  335: 'car',
#  336: 'boy',
#  337: 'days',
#  338: 'start',
#  339: 'sweet',
#  340: 'birthday',
#  341: 'wk',
#  342: 'world',
#  343: 'wanna',
#  344: 'shows',
#  345: 'another',
#  346: 'watching',
#  347: 'into',
#  348: 'problem',
#  349: 'guess',
#  350: 'ever',
#  351: 'bit',
#  352: 'video',
#  353: 'girl',
#  354: 'xxx',
#  355: 'big',
#  356: 'shit',
#  357: 'early',
#  358: 'awarded',
#  359: 'å£1000',
#  360: 'luv',
#  361: 'nothing',
#  362: 'sat',
#  363: 'dat',
#  364: 'dinner',
#  365: 'camera',
#  366: 'apply',
#  367: 'latest',
#  368: 'baby',
#  369: 'princess',
#  370: 'pa',
#  371: 'code',
#  372: 'hear',
#  373: 'because',
#  374: 'forgot',
#  375: 'ah',
#  376: 'shall',
#  377: 'liao',
#  378: 'remember',
#  379: 'everything',
#  380: 'bed',
#  381: 'jus',
#  382: 'fun',
#  383: 'shopping',
#  384: 'left',
#  385: 'bt',
#  386: 'guys',
#  387: 'offer',
#  388: 'thanx',
#  389: 'working',
#  390: 'probably',
#  391: 'month',
#  392: 'speak',
#  393: 'watch',
#  394: 'called',
#  395: 'didnt',
#  396: 'once',
#  397: "he's",
#  398: '10',
#  399: 'word',
#  400: "how's",
#  401: 'landline',
#  402: 'quite',
#  403: 'plan',
#  404: 'tv',
#  405: 'between',
#  406: 'two',
#  407: '9',
#  408: 'aight',
#  409: 'dis',
#  410: 'cost',
#  411: '150ppm',
#  412: 'reach',
#  413: 'hour',
#  414: 'thank',
#  415: 'afternoon',
#  416: 'box',
#  417: 'rate',
#  418: 'selected',
#  419: 'fuck',
#  420: 'minutes',
#  421: 'wake',
#  422: 'bus',
#  423: 'wont',
#  424: 'most',
#  425: 'missing',
#  426: 'looking',
#  427: 'part',
#  428: 'asked',
#  429: 'school',
#  430: 'bad',
#  431: 'put',
#  432: 'room',
#  433: 'dad',
#  434: 'face',
#  435: 'office',
#  436: 'wif',
#  437: 'enough',
#  438: 'look',
#  439: 'kiss',
#  440: 'until',
#  441: 'orange',
#  442: 'mail',
#  443: 'll',
#  444: "there's",
#  445: '2nd',
#  446: 'might',
#  447: 'award',
#  448: 'ringtone',
#  449: 'sexy',
#  450: 'm',
#  451: 'den',
#  452: 'pay',
#  453: 'true',
#  454: 'leh',
#  455: 'came',
#  456: 'anyway',
#  457: 'pain',
#  458: 'little',
#  459: 'tmr',
#  460: 'made',
#  461: 'wife',
#  462: 'okay',
#  463: '000',
#  464: 'collection',
#  465: 'evening',
#  466: 'weekend',
#  467: 'without',
#  468: 'show',
#  469: 'po',
#  470: 'means',
#  471: 'easy',
#  472: 'goes',
#  473: 'g',
#  474: 'abt',
#  475: 'plus',
#  476: 'details',
#  477: 'network',
#  478: 'says',
#  479: 'town',
#  480: 'tones',
#  481: 'yesterday',
#  482: 'maybe',
#  483: 'actually',
#  484: 'since',
#  485: 'important',
#  486: 'calls',
#  487: 'makes',
#  488: '8',
#  489: 'dunno',
#  490: 'does',
#  491: 'texts',
#  492: 're',
#  493: 'yours',
#  494: 'music',
#  495: 'hurt',
#  496: 'else',
#  497: 'missed',
#  498: 'collect',
#  499: 'mob',
#  500: 'away',
#  501: 'years',
#  502: 'must',
#  503: 'stay',
#  504: 'making',
#  505: 'decimal',
#  506: 'those',
#  507: 'able',
#  508: 'xmas',
#  509: 'havent',
#  510: 'while',
#  511: '500',
#  512: 'valid',
#  513: 'hair',
#  514: 'wen',
#  515: 'though',
#  516: 'id',
#  517: 'hav',
#  518: 'guy',
#  519: 'game',
#  520: 'colour',
#  521: 'attempt',
#  522: 'de',
#  523: 'eve',
#  524: 'online',
#  525: 'games',
#  526: "what's",
#  527: 'juz',
#  528: 'change',
#  529: 'smiling',
#  530: 'price',
#  531: 'sae',
#  532: 'wanted',
#  533: 'net',
#  534: 'tot',
#  535: 'order',
#  536: 'dude',
#  537: 'dreams',
#  538: 'å£5000',
#  539: 'todays',
#  540: 'believe',
#  541: 'entry',
#  542: 'weekly',
#  543: 'worry',
#  544: '10p',
#  545: 'bring',
#  546: 'old',
#  547: 'comes',
#  548: 'test',
#  549: 'post',
#  550: 'til',
#  551: 'these',
#  552: 'sch',
#  553: 'words',
#  554: 'å£100',
#  555: 'trip',
#  556: 'together',
#  557: 'messages',
#  558: 'delivery',
#  559: 'goin',
#  560: 'sleeping',
#  561: 'await',
#  562: 'coz',
#  563: 'join',
#  564: 'gift',
#  565: 'vouchers',
#  566: 'mean',
#  567: 'shop',
#  568: 'friendship',
#  569: 'points',
#  570: 'lose',
#  571: 'wot',
#  572: 'book',
#  573: 'beautiful',
#  574: 'till',
#  575: 'congrats',
#  576: 'answer',
#  577: 'feeling',
#  578: 'update',
#  579: 'thinking',
#  580: 'everyone',
#  581: 'hot',
#  582: 'food',
#  583: "we're",
#  584: 'set',
#  585: 'saw',
#  586: 'busy',
#  587: 'sad',
#  588: 'leaving',
#  589: 'huh',
#  590: 'double',
#  591: 'yourself',
#  592: 'bonus',
#  593: 'national',
#  594: 'lei',
#  595: 'hours',
#  596: 'http',
#  597: 'plz',
#  598: 'wants',
#  599: '8007',
#  600: 'calling',
#  601: "we'll",
#  602: 'tomo',
#  603: 'driving',
#  604: 'unsubscribe',
#  605: "haven't",
#  606: 'question',
#  607: 'times',
#  608: 'story',
#  609: 'run',
#  610: 'land',
#  611: 'news',
#  612: 'tried',
#  613: 'okie',
#  614: '750',
#  615: 'ring',
#  616: 'alright',
#  617: 'lots',
#  618: 'worth',
#  619: 'date',
#  620: 'address',
#  621: 'private',
#  622: 'email',
#  623: "''",
#  624: 'head',
#  625: 'top',
#  626: 'full',
#  627: '86688',
#  628: 'close',
#  629: 'bored',
#  630: 'gd',
#  631: 'pub',
#  632: 'services',
#  633: 'movie',
#  634: 'msgs',
#  635: 'happen',
#  636: 'knw',
#  637: 'wid',
#  638: 'anytime',
#  639: 'tho',
#  640: 'company',
#  641: 'xx',
#  642: 'minute',
#  643: 'whats',
#  644: 'gone',
#  645: 'drink',
#  646: 'å£2000',
#  647: 'nite',
#  648: 'haf',
#  649: 'break',
#  650: 'gr8',
#  651: 'expires',
#  652: 'pounds',
#  653: 'rite',
#  654: 'started',
#  655: 'saying',
#  656: 'second',
#  657: "she's",
#  658: 'don',
#  659: 'took',
#  660: 'pm',
#  661: 'angry',
#  662: 'found',
#  663: 'info',
#  664: 'either',
#  665: 'charge',
#  666: 'club',
#  667: 'oso',
#  668: 'final',
#  669: 'drive',
#  670: 'sounds',
#  671: 'pic',
#  672: 'taking',
#  673: 'sis',
#  674: 'lesson',
#  675: 'each',
#  676: "you've",
#  677: 'neva',
#  678: 'nope',
#  679: '08000930705',
#  680: 'open',
#  681: 'boytoy',
#  682: '30',
#  683: 'opt',
#  684: 'awesome',
#  685: 'ard',
#  686: 'family',
#  687: 'ltd',
#  688: '100',
#  689: 'aft',
#  690: 'å£500',
#  691: 'finished',
#  692: 'statement',
#  693: 'identifier',
#  694: '11',
#  695: 'wil',
#  696: "c's",
#  697: 'forget',
#  698: 'takes',
#  699: 'lucky',
#  700: 'both',
#  701: 'anyone',
#  702: 'goodmorning',
#  703: 'mine',
#  704: 'f',
#  705: 'pics',
#  706: 'secret',
#  707: 'mates',
#  708: 'winner',
#  709: 'frnds',
#  710: 'ni8',
#  711: 'dating',
#  712: 'saturday',
#  713: 'camcorder',
#  714: 'kind',
#  715: 'cause',
#  716: 'crazy',
#  717: 'fancy',
#  718: 'loving',
#  719: 'savamob',
#  720: 'å£3',
#  721: '12hrs',
#  722: 'sister',
#  723: 'poly',
#  724: 'search',
#  725: 'sea',
#  726: 'frnd',
#  727: 'hmm',
#  728: 'happened',
#  729: 'weeks',
#  730: 'walk',
#  731: 'voucher',
#  732: 'w',
#  733: 'darlin',
#  734: 'wkly',
#  735: 'treat',
#  736: 'tc',
#  737: "won't",
#  738: 'pobox',
#  739: 'available',
#  740: '\x89û',
#  741: 'hold',
#  742: 'freemsg',
#  743: 'fast',
#  744: 'na',
#  745: 'mah',
#  746: 'girls',
#  747: 'party',
#  748: 'blue',
#  749: 'hit',
#  750: 'case',
#  751: 'college',
#  752: 'lets',
#  753: 'far',
#  754: 'wonderful',
#  755: 'touch',
#  756: 'choose',
#  757: 'prob',
#  758: 'wit',
#  759: 'chikku',
#  760: 'hows',
#  761: 'brother',
#  762: 'content',
#  763: 'etc',
#  764: 'fri',
#  765: 'park',
#  766: 'mrng',
#  767: 'friday',
#  768: 'valued',
#  769: 'offers',
#  770: 'auction',
#  771: 'carlos',
#  772: 'reading',
#  773: 'hard',
#  774: 'noe',
#  775: 'fr',
#  776: 'stupid',
#  777: 'fone',
#  778: 'used',
#  779: 'player',
#  780: 'frm',
#  781: 'numbers',
#  782: 'card',
#  783: 'lovely',
#  784: 'whatever',
#  785: 'march',
#  786: 'press',
#  787: 'å£350',
#  788: 'rs',
#  789: 'alone',
#  790: 'parents',
#  791: 'grins',
#  792: 'charged',
#  793: 'cum',
#  794: 'whole',
#  795: 'support',
#  796: 'enter',
#  797: 'pretty',
#  798: 'o',
#  799: 'bout',
#  800: 'decided',
#  801: "'",
#  802: 'sunday',
#  803: 'earlier',
#  804: 'tel',
#  805: 'complimentary',
#  806: 'sex',
#  807: 'listen',
#  808: 'extra',
#  809: 'smth',
#  810: 'hungry',
#  811: 'chennai',
#  812: 'telling',
#  813: 'sun',
#  814: 'seeing',
#  815: 'nt',
#  816: '2003',
#  817: 'un',
#  818: "doesn't",
#  819: 'die',
#  820: 'fucking',
#  821: 'mu',
#  822: 'bslvyl',
#  823: 'quiz',
#  824: 'gotta',
#  825: 'bank',
#  826: "you'll",
#  827: 'mobileupd8',
#  828: 'mr',
#  829: 'their',
#  830: 'smoke',
#  831: 'hand',
#  832: 'b4',
#  833: 'happiness',
#  834: 'course',
#  835: 'row',
#  836: 'operator',
#  837: 'snow',
#  838: 'simple',
#  839: 'finally',
#  840: 'drop',
#  841: 'meant',
#  842: 'reveal',
#  843: 'thinks',
#  844: 'wow',
#  845: 'gas',
#  846: 'st',
#  847: 'india',
#  848: 'å£250',
#  849: "i'd",
#  850: 'loved',
#  851: 'red',
#  852: 'supposed',
#  853: 'å£2',
#  854: 'wap',
#  855: 'read',
#  856: 'uncle',
#  857: 'area',
#  858: '87066',
#  859: 'questions',
#  860: 'comp',
#  861: 'picking',
#  862: 'safe',
#  863: 'txts',
#  864: 'rock',
#  865: 'dream',
#  866: 'reward',
#  867: 'least',
#  868: 'credit',
#  869: 'mate',
#  870: 'checking',
#  871: 'type',
#  872: '800',
#  873: 'redeemed',
#  874: '04',
#  875: 'mayb',
#  876: 'remove',
#  877: 'hee',
#  878: 'std',
#  879: 'couple',
#  880: 'ass',
#  881: "wasn't",
#  882: 'dnt',
#  883: 'cut',
#  884: 'side',
#  885: 'tired',
#  886: 'phones',
#  887: 'yr',
#  888: 'visit',
#  889: 'confirm',
#  890: 'police',
#  891: 'information',
#  892: 'correct',
#  893: 'mum',
#  894: 'computer',
#  895: 'yar',
#  896: 'met',
#  897: 'motorola',
#  898: 'slow',
#  899: 'gn',
#  900: 'age',
#  901: 'wrong',
#  902: 'almost',
#  903: 'own',
#  904: 'whenever',
#  905: 'difficult',
#  906: 'caller',
#  907: 'somebody',
#  908: 'ha',
#  909: 'film',
#  910: 'gal',
#  911: 'blood',
#  912: 'discount',
#  913: '20',
#  914: 'outside',
#  915: 'ten',
#  916: 'plans',
#  917: 'rental',
#  918: 'oops',
#  919: 'mm',
#  920: 'congratulations',
#  921: 'within',
#  922: 'song',
#  923: 'heard',
#  924: 'different',
#  925: 'shower',
#  926: 'via',
#  927: 'oredi',
#  928: 'rakhesh',
#  929: 'link',
#  930: 'direct',
#  931: 'asap',
#  932: 'project',
#  933: 'orchard',
#  934: 'balance',
#  935: 'point',
#  936: 'hmmm',
#  937: 'currently',
#  938: 'wonder',
#  939: 'ipod',
#  940: 'store',
#  941: 'small',
#  942: 'reason',
#  943: 'tickets',
#  944: 'hmv',
#  945: 'figure',
#  946: 'gets',
#  947: 'eh',
#  948: 'laptop',
#  949: 'cheap',
#  950: 'wana',
#  951: 'match',
#  952: 'mom',
#  953: 'worried',
#  954: 'askd',
#  955: 'move',
#  956: 'understand',
#  957: 'entered',
#  958: 'felt',
#  959: 'abiola',
#  960: 'study',
#  961: 'ago',
#  962: 'ends',
#  963: 'callertune',
#  964: 'th',
#  965: 'log',
#  966: 'father',
#  967: 'slowly',
#  968: 'light',
#  969: 'sound',
#  970: '12',
#  971: 'lovable',
#  972: 'bath',
#  973: 'surprise',
#  974: 'rply',
#  975: 'men',
#  976: 'knew',
#  977: 'starting',
#  978: 'gym',
#  979: 'rest',
#  980: 'through',
#  981: 'comin',
#  982: '\x89ûò',
#  983: 'admirer',
#  984: 'ans',
#  985: 'bill',
#  986: 'å£800',
#  987: 'kate',
#  988: 'luck',
#  989: 'spend',
#  990: 'energy',
#  991: 'moral',
#  992: 'noon',
#  993: 'dead',
#  994: 'glad',
#  995: 'doin',
#  996: 'p',
#  997: 'empty',
#  998: 'moment',
#  999: 'otherwise',
#  1000: 'poor',
#  ...}

# %% [markdown]
# **Creating model and Adding the layers**

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# **Compile the model**

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 150, 32)           260768
#
#  lstm_1 (LSTM)               (None, 100)               53200
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 20)                2020
#
#  dropout_3 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 316,009
# Trainable params: 316,009
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Fit the model**

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 14s 378ms/step - loss: 0.4797 - accuracy: 0.8572 - val_loss: 0.3590 - val_accuracy: 0.8449
# Epoch 2/10
# 30/30 [==============================] - 11s 360ms/step - loss: 0.2059 - accuracy: 0.9348 - val_loss: 0.1174 - val_accuracy: 0.9768

# %% [markdown]
# **Save the model**

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# **Test the model**

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0981 - accuracy: 0.9809

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.098
#   Accuracy: 0.981
