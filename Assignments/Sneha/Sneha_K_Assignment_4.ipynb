# %% [markdown]
# **Importing** **the** **libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# **Reading** **the** **dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# **Process the data**

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ..., 559,  14, 640],
#        [  0,   0,   0, ..., 673,   5, 987],
#        [  0,   0,   0, ...,   6, 470, 642],
#        ...,
#        [  0,   0,   0, ...,   0,   1, 364],
#        [  0,   0,   0, ...,  43,  42,  60],
#        [  0,   0,   0, ..., 371, 355, 250]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: '2',
#  20: 'that',
#  21: 'now',
#  22: 'are',
#  23: 'so',
#  24: 'but',
#  25: 'not',
#  26: 'can',
#  27: 'or',
#  28: 'do',
#  29: 'at',
#  30: 'be',
#  31: 'with',
#  32: 'get',
#  33: 'will',
#  34: "i'm",
#  35: 'if',
#  36: 'ur',
#  37: 'just',
#  38: 'we',
#  39: 'no',
#  40: 'this',
#  41: '4',
#  42: 'gt',
#  43: 'lt',
#  44: 'up',
#  45: 'when',
#  46: 'ok',
#  47: 'free',
#  48: 'go',
#  49: 'all',
#  50: 'from',
#  51: 'out',
#  52: 'how',
#  53: 'what',
#  54: 'like',
#  55: 'know',
#  56: 'good',
#  57: 'was',
#  58: 'got',
#  59: 'then',
#  60: 'come',
#  61: 'am',
#  62: 'its',
#  63: 'day',
#  64: 'only',
#  65: 'time',
#  66: 'send',
#  67: 'love',
#  68: 'there',
#  69: 'text',
#  70: 'he',
#  71: 'want',
#  72: 'as',
#  73: 'txt',
#  74: 'by',
#  75: 'home',
#  76: 'one',
#  77: 'r',
#  78: "i'll",
#  79: 'sorry',
#  80: 'need',
#  81: 'going',
#  82: 'stop',
#  83: 'about',
#  84: 'lor',
#  85: 'back',
#  86: 'n',
#  87: 'still',
#  88: 'see',
#  89: 'today',
#  90: 'da',
#  91: 'our',
#  92: 'reply',
#  93: 'she',
#  94: 'mobile',
#  95: 'k',
#  96: 'hi',
#  97: "don't",
#  98: 'new',
#  99: 'take',
#  100: 'her',
#  101: 'later',
#  102: 'pls',
#  103: 'tell',
#  104: 'any',
#  105: 'please',
#  106: 'think',
#  107: 'week',
#  108: 'been',
#  109: 'dont',
#  110: 'phone',
#  111: 'here',
#  112: 'has',
#  113: 'dear',
#  114: 'did',
#  115: 'ì',
#  116: 'well',
#  117: '1',
#  118: 'claim',
#  119: 'night',
#  120: 'they',
#  121: 'some',
#  122: 'much',
#  123: 'who',
#  124: 'msg',
#  125: 'hope',
#  126: 'where',
#  127: 'happy',
#  128: 'great',
#  129: 'hey',
#  130: 'him',
#  131: 'an',
#  132: 'way',
#  133: 'd',
#  134: 'make',
#  135: 'oh',
#  136: 'too',
#  137: 'yes',
#  138: 'had',
#  139: 'more',
#  140: 'give',
#  141: 'work',
#  142: 'c',
#  143: 'number',
#  144: 'message',
#  145: 'right',
#  146: 'prize',
#  147: 'tomorrow',
#  148: 'already',
#  149: 'www',
#  150: 'e',
#  151: 'after',
#  152: 'wat',
#  153: 'should',
#  154: "it's",
#  155: 'say',
#  156: 'doing',
#  157: 'said',
#  158: 'amp',
#  159: 'yeah',
#  160: 'meet',
#  161: 'cash',
#  162: 'very',
#  163: 'really',
#  164: 'life',
#  165: '3',
#  166: 'ask',
#  167: 'im',
#  168: 'them',
#  169: 'why',
#  170: 'morning',
#  171: 'babe',
#  172: 't',
#  173: 'miss',
#  174: 'last',
#  175: 'thanks',
#  176: 'win',
#  177: 'find',
#  178: 'would',
#  179: 'care',
#  180: 'won',
#  181: 'let',
#  182: 'cos',
#  183: 'urgent',
#  184: 'also',
#  185: 'sent',
#  186: 'every',
#  187: 'lol',
#  188: 'uk',
#  189: 'before',
#  190: 'anything',
#  191: '150p',
#  192: 'pick',
#  193: 'over',
#  194: 'b',
#  195: "i've",
#  196: 'sure',
#  197: 'us',
#  198: 'nokia',
#  199: 'next',
#  200: 'keep',
#  201: 'com',
#  202: 'contact',
#  203: 'many',
#  204: 'something',
#  205: 's',
#  206: 'min',
#  207: 'again',
#  208: 'cant',
#  209: 'feel',
#  210: 'wait',
#  211: 'were',
#  212: 'nice',
#  213: '5',
#  214: 'thing',
#  215: 'soon',
#  216: '50',
#  217: 'which',
#  218: 'place',
#  219: 'ya',
#  220: 'around',
#  221: 'off',
#  222: 'went',
#  223: 'leave',
#  224: 'money',
#  225: 'down',
#  226: 'gonna',
#  227: 'late',
#  228: 'v',
#  229: 'co',
#  230: 'always',
#  231: 'tonight',
#  232: 'first',
#  233: 'tone',
#  234: 'his',
#  235: 'could',
#  236: 'sleep',
#  237: 'gud',
#  238: 'friends',
#  239: 'even',
#  240: 'someone',
#  241: 'customer',
#  242: 'x',
#  243: 'buy',
#  244: 'special',
#  245: 'thk',
#  246: "you're",
#  247: 'hello',
#  248: 'sms',
#  249: 'may',
#  250: '18',
#  251: 'per',
#  252: 'year',
#  253: 'heart',
#  254: 'waiting',
#  255: 'getting',
#  256: 'guaranteed',
#  257: '16',
#  258: 'people',
#  259: 'ìï',
#  260: 'told',
#  261: 'haha',
#  262: 'dun',
#  263: 'wan',
#  264: "can't",
#  265: "that's",
#  266: 'holiday',
#  267: 'mins',
#  268: 'use',
#  269: 'wish',
#  270: 'service',
#  271: 'chat',
#  272: 'help',
#  273: '6',
#  274: 'coming',
#  275: 'other',
#  276: 'things',
#  277: 'fine',
#  278: 'thought',
#  279: 'yet',
#  280: 'man',
#  281: 'cs',
#  282: 'talk',
#  283: 'try',
#  284: 'name',
#  285: 'house',
#  286: 'same',
#  287: 'draw',
#  288: 'smile',
#  289: 'bit',
#  290: 'live',
#  291: 'stuff',
#  292: 'days',
#  293: 'lunch',
#  294: 'thats',
#  295: 'y',
#  296: 'few',
#  297: 'ill',
#  298: 'done',
#  299: '7',
#  300: 'friend',
#  301: 'never',
#  302: 'trying',
#  303: 'finish',
#  304: 'best',
#  305: 'long',
#  306: "didn't",
#  307: 'play',
#  308: 'cool',
#  309: 'because',
#  310: 'line',
#  311: 'check',
#  312: 'lot',
#  313: 'being',
#  314: 'better',
#  315: 'class',
#  316: 'mind',
#  317: 'eat',
#  318: 'latest',
#  319: 'å£1',
#  320: 'yup',
#  321: 'camera',
#  322: 'car',
#  323: 'wanna',
#  324: 'wk',
#  325: 'having',
#  326: 'person',
#  327: 'enjoy',
#  328: 'word',
#  329: 'account',
#  330: 'shows',
#  331: 'problem',
#  332: 'job',
#  333: 'end',
#  334: 'dat',
#  335: 'meeting',
#  336: 'sir',
#  337: '1st',
#  338: 'awarded',
#  339: 'world',
#  340: 'liao',
#  341: 'another',
#  342: 'watching',
#  343: 'might',
#  344: 'than',
#  345: 'bed',
#  346: 'nothing',
#  347: 'landline',
#  348: 'shit',
#  349: 'ready',
#  350: 'big',
#  351: 'receive',
#  352: 'dinner',
#  353: 'guys',
#  354: 'yo',
#  355: '150ppm',
#  356: 'ever',
#  357: 'into',
#  358: 'cost',
#  359: 'half',
#  360: 'room',
#  361: 'bad',
#  362: 'xxx',
#  363: 'video',
#  364: 'guess',
#  365: 'bt',
#  366: 'luv',
#  367: 'month',
#  368: 'apply',
#  369: 'thanx',
#  370: 'å£1000',
#  371: 'box',
#  372: 'quite',
#  373: 'weekend',
#  374: 'lar',
#  375: 'forgot',
#  376: 'real',
#  377: 'offer',
#  378: 'working',
#  379: 'code',
#  380: 'birthday',
#  381: 'office',
#  382: 'dis',
#  383: 'hour',
#  384: 'jus',
#  385: 'girl',
#  386: 'early',
#  387: 'remember',
#  388: 'ah',
#  389: 'baby',
#  390: 'dunno',
#  391: 'anyway',
#  392: 'kiss',
#  393: 'chance',
#  394: 'plan',
#  395: 'shall',
#  396: 'start',
#  397: 'leh',
#  398: '9',
#  399: '10',
#  400: 'does',
#  401: 'shopping',
#  402: 'speak',
#  403: 'watch',
#  404: 'ringtone',
#  405: 'minutes',
#  406: 'says',
#  407: 'princess',
#  408: 'missing',
#  409: 'sweet',
#  410: 'hear',
#  411: 'those',
#  412: 'put',
#  413: 'god',
#  414: 'wont',
#  415: 'left',
#  416: 'calls',
#  417: 'maybe',
#  418: 'easy',
#  419: 'sat',
#  420: 'bus',
#  421: "how's",
#  422: 'part',
#  423: 'called',
#  424: 'network',
#  425: 'fun',
#  426: 'rate',
#  427: 'until',
#  428: 'probably',
#  429: 'po',
#  430: 'two',
#  431: 'wife',
#  432: 'pay',
#  433: 'once',
#  434: 'didnt',
#  435: 'looking',
#  436: 'plz',
#  437: 'pa',
#  438: 'evening',
#  439: 'wot',
#  440: 'collect',
#  441: 'between',
#  442: 'enough',
#  443: 'hav',
#  444: 'texts',
#  445: 'tv',
#  446: 'abt',
#  447: 'okay',
#  448: 'm',
#  449: 'selected',
#  450: 'aight',
#  451: 'reach',
#  452: 'den',
#  453: 'while',
#  454: 'tmr',
#  455: 'look',
#  456: 'xmas',
#  457: 'collection',
#  458: 'decimal',
#  459: 'll',
#  460: 'thank',
#  461: 'actually',
#  462: 'though',
#  463: '000',
#  464: 'entry',
#  465: 'afternoon',
#  466: 'school',
#  467: 'dad',
#  468: 'little',
#  469: 'face',
#  470: 'havent',
#  471: 'means',
#  472: 'town',
#  473: 'orange',
#  474: 'messages',
#  475: 'boy',
#  476: 'valid',
#  477: 'sexy',
#  478: 'years',
#  479: 'show',
#  480: 'times',
#  481: 'alright',
#  482: 'made',
#  483: '8',
#  484: "he's",
#  485: 'gift',
#  486: 'till',
#  487: 'missed',
#  488: 'worry',
#  489: 'award',
#  490: 'mob',
#  491: 'weekly',
#  492: 'stay',
#  493: 'sch',
#  494: 'juz',
#  495: 'de',
#  496: 'pain',
#  497: 'goes',
#  498: 'came',
#  499: 'hurt',
#  500: 'mail',
#  501: 'able',
#  502: 'bring',
#  503: '2nd',
#  504: 'everything',
#  505: 'bored',
#  506: 'join',
#  507: 'beautiful',
#  508: 're',
#  509: 'since',
#  510: 'details',
#  511: 'without',
#  512: 'til',
#  513: 'lei',
#  514: 'guy',
#  515: 'true',
#  516: 'words',
#  517: "there's",
#  518: "''",
#  519: 'yesterday',
#  520: 'asked',
#  521: 'å£100',
#  522: 'most',
#  523: 'wif',
#  524: 'wanted',
#  525: 'online',
#  526: '10p',
#  527: 'else',
#  528: 'away',
#  529: 'update',
#  530: 'driving',
#  531: 'colour',
#  532: 'run',
#  533: 'double',
#  534: 'plus',
#  535: 'tones',
#  536: 'nite',
#  537: 'shop',
#  538: 'ard',
#  539: 'friendship',
#  540: 'these',
#  541: 'points',
#  542: "won't",
#  543: 'makes',
#  544: 'calling',
#  545: 'wen',
#  546: 'fuck',
#  547: 'wid',
#  548: 'eve',
#  549: 'must',
#  550: 'saw',
#  551: 'trip',
#  552: 'music',
#  553: 'making',
#  554: 'sleeping',
#  555: 'hair',
#  556: 'price',
#  557: 'wake',
#  558: 'lose',
#  559: 'sad',
#  560: 'change',
#  561: 'address',
#  562: 'oso',
#  563: 'family',
#  564: 'smiling',
#  565: 'sae',
#  566: 'mean',
#  567: 'together',
#  568: 'either',
#  569: 'coz',
#  570: 'noe',
#  571: 'set',
#  572: 'top',
#  573: 'net',
#  574: 'yours',
#  575: 'å£2000',
#  576: 'test',
#  577: 'huh',
#  578: 'full',
#  579: 'answer',
#  580: 'g',
#  581: 'believe',
#  582: 'å£5000',
#  583: 'bonus',
#  584: 'club',
#  585: 'important',
#  586: 'happen',
#  587: 'ring',
#  588: 'await',
#  589: 'chikku',
#  590: 'movie',
#  591: 'private',
#  592: 'story',
#  593: 'pics',
#  594: 'started',
#  595: "we're",
#  596: 'attempt',
#  597: 'tot',
#  598: 'national',
#  599: 'hours',
#  600: 'news',
#  601: '500',
#  602: 'yourself',
#  603: 'pic',
#  604: 'feeling',
#  605: 'wants',
#  606: 'question',
#  607: "we'll",
#  608: 'comes',
#  609: '11',
#  610: 'lets',
#  611: 'dude',
#  612: 'thinking',
#  613: 'å£500',
#  614: 'email',
#  615: 'delivery',
#  616: 'post',
#  617: 'tomo',
#  618: "what's",
#  619: 'id',
#  620: 'statement',
#  621: 'expires',
#  622: 'smoke',
#  623: 'cause',
#  624: 'tried',
#  625: 'wil',
#  626: 'order',
#  627: 'poly',
#  628: 'second',
#  629: 'hot',
#  630: 'goin',
#  631: 'gr8',
#  632: '8007',
#  633: 'congrats',
#  634: '750',
#  635: 'date',
#  636: 'game',
#  637: 'games',
#  638: 'everyone',
#  639: 'todays',
#  640: 'xx',
#  641: 'fast',
#  642: 'finished',
#  643: 'saturday',
#  644: 'pub',
#  645: 'takes',
#  646: 'neva',
#  647: 'aft',
#  648: 'brother',
#  649: 'needs',
#  650: 'close',
#  651: 'break',
#  652: 'head',
#  653: "haven't",
#  654: 'identifier',
#  655: 'taking',
#  656: 'vouchers',
#  657: 'both',
#  658: 'old',
#  659: 'rite',
#  660: 'sounds',
#  661: 'frnd',
#  662: 'voucher',
#  663: 'book',
#  664: 'minute',
#  665: 'dreams',
#  666: 'leaving',
#  667: 'angry',
#  668: 'lots',
#  669: 'smth',
#  670: 'awesome',
#  671: '12hrs',
#  672: 'haf',
#  673: "she's",
#  674: 'pretty',
#  675: 'treat',
#  676: 'drop',
#  677: 'loving',
#  678: 'parents',
#  679: 'drink',
#  680: 'pounds',
#  681: 'choose',
#  682: 'pobox',
#  683: 'okie',
#  684: 'oredi',
#  685: 'busy',
#  686: 'pm',
#  687: "c's",
#  688: 'far',
#  689: 'simple',
#  690: 'happened',
#  691: 'http',
#  692: 'saying',
#  693: 'row',
#  694: 'tho',
#  695: 'sis',
#  696: 'sister',
#  697: 'food',
#  698: 'nope',
#  699: 'final',
#  700: 'auction',
#  701: 'college',
#  702: '\x89û',
#  703: 'goodmorning',
#  704: 'seeing',
#  705: 'boytoy',
#  706: 'search',
#  707: 'card',
#  708: 'mates',
#  709: 'player',
#  710: 'alone',
#  711: 'ni8',
#  712: 'each',
#  713: 'drive',
#  714: 'chennai',
#  715: 'available',
#  716: 'wrong',
#  717: 'wit',
#  718: 'worth',
#  719: 'knw',
#  720: 'took',
#  721: 'friday',
#  722: 'kind',
#  723: 'read',
#  724: 'gone',
#  725: 'quiz',
#  726: 'sun',
#  727: 'winner',
#  728: 'decided',
#  729: 'anyone',
#  730: 'course',
#  731: 'lesson',
#  732: 'dating',
#  733: 'congratulations',
#  734: 'hard',
#  735: 'whats',
#  736: 'gd',
#  737: 'anytime',
#  738: '08000930705',
#  739: 'secret',
#  740: 'found',
#  741: 'bout',
#  742: 'forget',
#  743: 'info',
#  744: 'land',
#  745: 'light',
#  746: 'sea',
#  747: 'w',
#  748: 'charge',
#  749: 'fri',
#  750: 'services',
#  751: 'happiness',
#  752: 'darlin',
#  753: 'company',
#  754: '86688',
#  755: 'operator',
#  756: 'prob',
#  757: 'used',
#  758: 'fancy',
#  759: 'understand',
#  760: 'crazy',
#  761: 'carlos',
#  762: 'felt',
#  763: 'nt',
#  764: 'opt',
#  765: '2003',
#  766: '800',
#  767: 'un',
#  768: 'visit',
#  769: 'hit',
#  770: 'open',
#  771: 'tel',
#  772: 'ass',
#  773: 'b4',
#  774: "doesn't",
#  775: 'camcorder',
#  776: 'almost',
#  777: 'girls',
#  778: 'walk',
#  779: 'their',
#  780: 'touch',
#  781: 'support',
#  782: 'lovely',
#  783: 'blue',
#  784: 'mah',
#  785: 'unlimited',
#  786: 'whatever',
#  787: 'outside',
#  788: 'fucking',
#  789: 'within',
#  790: 'unsubscribe',
#  791: 'hee',
#  792: 'frm',
#  793: 'valued',
#  794: 'o',
#  795: 'whole',
#  796: 'point',
#  797: 'tired',
#  798: 'å£250',
#  799: 'ha',
#  800: 'askd',
#  801: 'least',
#  802: 'redeemed',
#  803: '04',
#  804: 'ltd',
#  805: 'å£3',
#  806: 'snow',
#  807: '30',
#  808: 'luck',
#  809: 'hows',
#  810: 'mayb',
#  811: 'type',
#  812: 'hold',
#  813: 'wkly',
#  814: 'grins',
#  815: 'listen',
#  816: 'hungry',
#  817: 'mum',
#  818: 'hmmm',
#  819: 'side',
#  820: 'tc',
#  821: 'via',
#  822: 'thinks',
#  823: 'area',
#  824: 'phones',
#  825: 'mobileupd8',
#  826: '08000839402',
#  827: 'mu',
#  828: 'meant',
#  829: 'lucky',
#  830: 'msgs',
#  831: 'freemsg',
#  832: 'yar',
#  833: 'rs',
#  834: 'weeks',
#  835: 'heard',
#  836: 'finally',
#  837: 'reason',
#  838: 'party',
#  839: '100',
#  840: 'march',
#  841: 'wonderful',
#  842: 'motorola',
#  843: 'remove',
#  844: 'talking',
#  845: 'na',
#  846: 'sunday',
#  847: 'credit',
#  848: 'offers',
#  849: 'fone',
#  850: 'content',
#  851: 'wonder',
#  852: 'gym',
#  853: 'fr',
#  854: 'gotta',
#  855: 'numbers',
#  856: 'safe',
#  857: 'ten',
#  858: "i'd",
#  859: 'earlier',
#  860: 'wow',
#  861: 'seen',
#  862: 'frnds',
#  863: 'yr',
#  864: 'whenever',
#  865: 'savamob',
#  866: 'couple',
#  867: 'shower',
#  868: 'complimentary',
#  869: 'th',
#  870: 'mate',
#  871: 'abiola',
#  872: 'sound',
#  873: 'comp',
#  874: 'sending',
#  875: 'ipod',
#  876: '87066',
#  877: 'å£2',
#  878: 'truth',
#  879: 'sex',
#  880: 'supposed',
#  881: 'direct',
#  882: 'hand',
#  883: 'rest',
#  884: 'project',
#  885: 'computer',
#  886: 'move',
#  887: 'download',
#  888: 'balance',
#  889: 'currently',
#  890: 'suite342',
#  891: '2lands',
#  892: 'swing',
#  893: 'ugh',
#  894: 'stupid',
#  895: 'caller',
#  896: '03',
#  897: 'asap',
#  898: 'telling',
#  899: 'charged',
#  900: 'pass',
#  901: 'enter',
#  902: "'",
#  903: 'press',
#  904: 'st',
#  905: 'lost',
#  906: 'cum',
#  907: 'dnt',
#  908: 'mrng',
#  909: "you've",
#  910: 'police',
#  911: 'ac',
#  912: 'hmm',
#  913: 'etc',
#  914: 'loved',
#  915: 'moment',
#  916: 'exam',
#  917: 'kate',
#  918: 'die',
#  919: 'txting',
#  920: 'il',
#  921: 'asking',
#  922: 'pete',
#  923: 'slowly',
#  924: 'red',
#  925: 'usual',
#  926: 'usf',
#  927: 'reading',
#  928: 'entered',
#  929: "b'day",
#  930: 'invited',
#  931: 'kids',
#  932: 'comin',
#  933: 'india',
#  934: 'myself',
#  935: 'tickets',
#  936: 'eg',
#  937: 'sony',
#  938: "wasn't",
#  939: 'small',
#  940: 'ts',
#  941: 'questions',
#  942: 'checking',
#  943: 'dogging',
#  944: 'laugh',
#  945: 'tonite',
#  946: 'rental',
#  947: 'picking',
#  948: 'em',
#  949: 'reward',
#  950: 'christmas',
#  951: '12',
#  952: 'å£10',
#  953: 'mr',
#  954: 'eh',
#  955: 'rakhesh',
#  956: 'woke',
#  957: 'bslvyl',
#  958: 'mobiles',
#  959: 'case',
#  960: 'å£350',
#  961: 'txts',
#  962: 'sell',
#  963: 'orchard',
#  964: 'reveal',
#  965: 'std',
#  966: '20',
#  967: 'water',
#  968: 'loads',
#  969: 'laptop',
#  970: 'ans',
#  971: 'don',
#  972: 'through',
#  973: 'somebody',
#  974: 'sort',
#  975: 'semester',
#  976: 'confirm',
#  977: 'ends',
#  978: 'across',
#  979: 'leaves',
#  980: 'feels',
#  981: 'slow',
#  982: 'hoping',
#  983: 'plans',
#  984: 'father',
#  985: 'john',
#  986: 'cut',
#  987: 'street',
#  988: 'glad',
#  989: 'discount',
#  990: 'accept',
#  991: 'ringtones',
#  992: "you'll",
#  993: 'lazy',
#  994: 'representative',
#  995: 'sitting',
#  996: 'spend',
#  997: 'clean',
#  998: 'wine',
#  999: 'al',
#  1000: 'bank',
#  ...}

# %% [markdown]
# **Creating model and Adding the layers**

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# **Compile the model**

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           262080
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 317,321
# Trainable params: 317,321
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Fit the model**

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 15s 418ms/step - loss: 0.4414 - accuracy: 0.8656 - val_loss: 0.3274 - val_accuracy: 0.8513
# Epoch 2/10
# 30/30 [==============================] - 10s 349ms/step - loss: 0.2072 - accuracy: 0.9285 - val_loss: 0.1174 - val_accuracy: 0.9831

# %% [markdown]
# **Save the model**

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# **Test the model**

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1165 - accuracy: 0.9725

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.117
#   Accuracy: 0.972
