# %% [markdown]
# **Importing** **the** **libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# **Reading** **the** **dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# **Process the data**

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,  89,  57, 109],
#        [  0,   0,   0, ...,  41,  38, 181],
#        [  0,   0,   0, ..., 306, 699, 129],
#        ...,
#        [  0,   0,   0, ..., 340,   4, 120],
#        [  0,   0,   0, ...,  20,   6, 175],
#        [  0,   0,   0, ...,  30,   8, 441]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'have',
#  17: 'call',
#  18: 'on',
#  19: 'that',
#  20: '2',
#  21: 'now',
#  22: 'are',
#  23: 'so',
#  24: 'not',
#  25: 'but',
#  26: 'or',
#  27: 'at',
#  28: 'do',
#  29: 'can',
#  30: "i'm",
#  31: 'will',
#  32: 'if',
#  33: 'get',
#  34: 'be',
#  35: 'just',
#  36: 'with',
#  37: 'ur',
#  38: 'no',
#  39: 'we',
#  40: 'this',
#  41: '4',
#  42: 'up',
#  43: 'gt',
#  44: 'lt',
#  45: 'go',
#  46: 'ok',
#  47: 'how',
#  48: 'free',
#  49: 'all',
#  50: 'from',
#  51: 'what',
#  52: 'out',
#  53: 'know',
#  54: 'when',
#  55: 'then',
#  56: 'was',
#  57: 'good',
#  58: 'its',
#  59: 'like',
#  60: 'am',
#  61: 'come',
#  62: 'only',
#  63: 'day',
#  64: 'got',
#  65: 'time',
#  66: 'send',
#  67: 'love',
#  68: 'there',
#  69: 'want',
#  70: 'he',
#  71: 'text',
#  72: 'as',
#  73: 'going',
#  74: 'txt',
#  75: 'home',
#  76: "i'll",
#  77: 'sorry',
#  78: 'one',
#  79: 'by',
#  80: 'about',
#  81: 'lor',
#  82: 'n',
#  83: 'need',
#  84: 'da',
#  85: 'today',
#  86: 'stop',
#  87: 'back',
#  88: 'r',
#  89: 'k',
#  90: 'see',
#  91: 'still',
#  92: 'she',
#  93: 'our',
#  94: 'hi',
#  95: 'reply',
#  96: "don't",
#  97: 'mobile',
#  98: 'pls',
#  99: 'dont',
#  100: 'tell',
#  101: 'later',
#  102: 'please',
#  103: 'take',
#  104: 'been',
#  105: 'new',
#  106: 'her',
#  107: 'think',
#  108: 'any',
#  109: 'well',
#  110: 'they',
#  111: 'phone',
#  112: 'here',
#  113: 'week',
#  114: 'some',
#  115: 'dear',
#  116: 'did',
#  117: '1',
#  118: 'night',
#  119: 'claim',
#  120: 'great',
#  121: 'where',
#  122: 'hey',
#  123: 'hope',
#  124: 'ì',
#  125: 'has',
#  126: 'an',
#  127: 'much',
#  128: 'd',
#  129: 'too',
#  130: 'happy',
#  131: 'him',
#  132: 'msg',
#  133: 'oh',
#  134: 'more',
#  135: 'yes',
#  136: 'give',
#  137: 'make',
#  138: 'way',
#  139: 'who',
#  140: 'message',
#  141: 'c',
#  142: 'had',
#  143: 'work',
#  144: 'prize',
#  145: 'ask',
#  146: "it's",
#  147: 'e',
#  148: 'number',
#  149: 'www',
#  150: 'after',
#  151: 'already',
#  152: 'right',
#  153: 'should',
#  154: 'im',
#  155: 'meet',
#  156: 'really',
#  157: 'tomorrow',
#  158: 'wat',
#  159: 'say',
#  160: 'doing',
#  161: 'cash',
#  162: 'why',
#  163: 'said',
#  164: '3',
#  165: 'find',
#  166: 'morning',
#  167: 'yeah',
#  168: 'last',
#  169: 'babe',
#  170: 'very',
#  171: 'them',
#  172: 'lol',
#  173: 'amp',
#  174: 'b',
#  175: 'also',
#  176: 'would',
#  177: 'thanks',
#  178: 'life',
#  179: 'cos',
#  180: 'won',
#  181: '150p',
#  182: 'anything',
#  183: 'before',
#  184: 'every',
#  185: 'uk',
#  186: 'nokia',
#  187: 'pick',
#  188: 'sure',
#  189: 'urgent',
#  190: 't',
#  191: 'miss',
#  192: 'win',
#  193: 'let',
#  194: 'sent',
#  195: 'again',
#  196: 'something',
#  197: 'buy',
#  198: 'first',
#  199: 'care',
#  200: "i've",
#  201: 'com',
#  202: 'us',
#  203: 'over',
#  204: 'keep',
#  205: 'even',
#  206: 'feel',
#  207: 'min',
#  208: 'nice',
#  209: 'went',
#  210: 'late',
#  211: 'cant',
#  212: 'wait',
#  213: 'place',
#  214: 'were',
#  215: 'money',
#  216: 'thing',
#  217: 'which',
#  218: 'next',
#  219: '5',
#  220: 'gonna',
#  221: 'his',
#  222: 'wan',
#  223: 'someone',
#  224: 'contact',
#  225: "can't",
#  226: 'off',
#  227: 'leave',
#  228: 'many',
#  229: 'tonight',
#  230: 'co',
#  231: "that's",
#  232: 'service',
#  233: 'tone',
#  234: 'sleep',
#  235: 'soon',
#  236: 'chat',
#  237: 'sms',
#  238: 's',
#  239: 'coming',
#  240: 'dun',
#  241: 'around',
#  242: 'hello',
#  243: 'down',
#  244: 'customer',
#  245: 'ya',
#  246: 'v',
#  247: 'x',
#  248: 'always',
#  249: 'guaranteed',
#  250: '50',
#  251: 'friends',
#  252: '18',
#  253: '16',
#  254: 'things',
#  255: 'try',
#  256: 'same',
#  257: 'wish',
#  258: 'could',
#  259: 'gud',
#  260: 'name',
#  261: 'ìï',
#  262: 'thk',
#  263: 'other',
#  264: 'getting',
#  265: 'special',
#  266: 'waiting',
#  267: 'best',
#  268: 'per',
#  269: 'holiday',
#  270: 'stuff',
#  271: 'help',
#  272: 'told',
#  273: 'may',
#  274: 'yet',
#  275: 'days',
#  276: 'done',
#  277: 'fine',
#  278: "you're",
#  279: 'man',
#  280: 'year',
#  281: 'cs',
#  282: 'house',
#  283: 'mins',
#  284: 'friend',
#  285: 'use',
#  286: 'haha',
#  287: 'line',
#  288: 'lunch',
#  289: 'smile',
#  290: 'people',
#  291: 'talk',
#  292: 'thought',
#  293: 'y',
#  294: 'heart',
#  295: 'draw',
#  296: 'class',
#  297: 'being',
#  298: 'better',
#  299: 'trying',
#  300: 'few',
#  301: "didn't",
#  302: 'problem',
#  303: 'wanna',
#  304: 'finish',
#  305: 'enjoy',
#  306: '6',
#  307: 'ill',
#  308: 'play',
#  309: 'yup',
#  310: 'sir',
#  311: 'never',
#  312: 'cool',
#  313: 'latest',
#  314: 'ready',
#  315: 'than',
#  316: 'nothing',
#  317: 'having',
#  318: 'bit',
#  319: 'car',
#  320: 'check',
#  321: 'half',
#  322: 'live',
#  323: 'ah',
#  324: 'person',
#  325: 'into',
#  326: 'account',
#  327: 'god',
#  328: 'eat',
#  329: 'long',
#  330: 'lar',
#  331: 'camera',
#  332: 'end',
#  333: 'meeting',
#  334: 'yo',
#  335: '1st',
#  336: 'awarded',
#  337: '7',
#  338: 'chance',
#  339: 'å£1000',
#  340: 'guys',
#  341: 'start',
#  342: 'birthday',
#  343: 'å£1',
#  344: 'dinner',
#  345: 'xxx',
#  346: 'once',
#  347: 'dat',
#  348: 'mind',
#  349: 'job',
#  350: 'quite',
#  351: 'guess',
#  352: 'shows',
#  353: 'word',
#  354: 'month',
#  355: 'pa',
#  356: 'another',
#  357: 'luv',
#  358: 'thats',
#  359: 'liao',
#  360: 'called',
#  361: 'wk',
#  362: 'big',
#  363: 'speak',
#  364: 'box',
#  365: '150ppm',
#  366: 'early',
#  367: 'offer',
#  368: 'because',
#  369: 'cost',
#  370: 'girl',
#  371: 'maybe',
#  372: 'look',
#  373: 'thanx',
#  374: 'jus',
#  375: 'landline',
#  376: 'lot',
#  377: 'actually',
#  378: 'video',
#  379: 'plan',
#  380: 'tv',
#  381: 'remember',
#  382: 'receive',
#  383: 'office',
#  384: 'sweet',
#  385: 'sat',
#  386: 'probably',
#  387: 'bad',
#  388: 'real',
#  389: 'watching',
#  390: 'shit',
#  391: 'boy',
#  392: 'might',
#  393: 'face',
#  394: 'princess',
#  395: 'reach',
#  396: 'two',
#  397: 'baby',
#  398: 'shopping',
#  399: 'll',
#  400: 'aight',
#  401: 'while',
#  402: 'pay',
#  403: 'code',
#  404: 'ever',
#  405: 'weekend',
#  406: 'room',
#  407: 'den',
#  408: 'orange',
#  409: 'm',
#  410: 'minutes',
#  411: 'wont',
#  412: '000',
#  413: 'world',
#  414: 'hear',
#  415: 'does',
#  416: 'dis',
#  417: 'afternoon',
#  418: 'fun',
#  419: 'dad',
#  420: 'little',
#  421: 'watch',
#  422: 'forgot',
#  423: 'wife',
#  424: 'until',
#  425: 'came',
#  426: 'bed',
#  427: 'able',
#  428: 'part',
#  429: '9',
#  430: 'bt',
#  431: 'fuck',
#  432: 'network',
#  433: "he's",
#  434: 'tmr',
#  435: 'since',
#  436: 'hour',
#  437: 'shall',
#  438: 'hav',
#  439: 'didnt',
#  440: 'award',
#  441: 'bus',
#  442: 'price',
#  443: 'working',
#  444: 'po',
#  445: 'rate',
#  446: 'left',
#  447: 'selected',
#  448: 'between',
#  449: 'says',
#  450: 'apply',
#  451: 'evening',
#  452: 'anyway',
#  453: 'those',
#  454: 'mail',
#  455: 'looking',
#  456: 'thank',
#  457: 'show',
#  458: '10',
#  459: 'put',
#  460: 'asked',
#  461: 'times',
#  462: 'ringtone',
#  463: 'texts',
#  464: 'important',
#  465: 'though',
#  466: 'goes',
#  467: 'valid',
#  468: 'leh',
#  469: 'guy',
#  470: 'wot',
#  471: 'enough',
#  472: 'wake',
#  473: '8',
#  474: 'wanted',
#  475: 'without',
#  476: 'sexy',
#  477: 'else',
#  478: 'de',
#  479: 'collection',
#  480: 'okay',
#  481: 'address',
#  482: 'update',
#  483: 'collect',
#  484: 'messages',
#  485: 'town',
#  486: 'everything',
#  487: 'dunno',
#  488: 'pain',
#  489: '2nd',
#  490: 'stay',
#  491: 'wif',
#  492: 'plz',
#  493: 'school',
#  494: 'tones',
#  495: 'plus',
#  496: 'gift',
#  497: 'details',
#  498: "how's",
#  499: 'double',
#  500: 'true',
#  501: 'dude',
#  502: 'abt',
#  503: 'yours',
#  504: "there's",
#  505: 'years',
#  506: 'feeling',
#  507: 'havent',
#  508: "what's",
#  509: "''",
#  510: 'å£100',
#  511: 'easy',
#  512: 'must',
#  513: 'missed',
#  514: 'coz',
#  515: 'juz',
#  516: 'making',
#  517: 'entry',
#  518: 'bring',
#  519: 'worry',
#  520: 'away',
#  521: 'mob',
#  522: 'nite',
#  523: 'goin',
#  524: 'yesterday',
#  525: 'alright',
#  526: 'made',
#  527: 'saw',
#  528: 'å£5000',
#  529: 'ard',
#  530: 'movie',
#  531: 'wants',
#  532: 'wid',
#  533: 'set',
#  534: 'wen',
#  535: 'todays',
#  536: 're',
#  537: 'yourself',
#  538: 'hours',
#  539: 'book',
#  540: 'calls',
#  541: 'run',
#  542: 'till',
#  543: 'food',
#  544: 'game',
#  545: 'haf',
#  546: 'missing',
#  547: 'these',
#  548: 'xmas',
#  549: 'words',
#  550: 'hot',
#  551: 'g',
#  552: 'leaving',
#  553: 'makes',
#  554: 'most',
#  555: 'http',
#  556: 'both',
#  557: 'either',
#  558: 'id',
#  559: 'together',
#  560: 'friendship',
#  561: 'sleeping',
#  562: 'family',
#  563: 'join',
#  564: 'attempt',
#  565: 'net',
#  566: 'answer',
#  567: 'top',
#  568: 'test',
#  569: "we'll",
#  570: "haven't",
#  571: 'shop',
#  572: 'online',
#  573: '10p',
#  574: "we're",
#  575: 'kiss',
#  576: 'full',
#  577: 'delivery',
#  578: 'sch',
#  579: 'driving',
#  580: 'bonus',
#  581: 'til',
#  582: 'pic',
#  583: 'congrats',
#  584: 'happen',
#  585: 'await',
#  586: 'sae',
#  587: 'news',
#  588: 'lei',
#  589: 'tot',
#  590: 'club',
#  591: 'music',
#  592: 'tried',
#  593: 'å£2000',
#  594: 'means',
#  595: 'believe',
#  596: 'story',
#  597: 'oso',
#  598: 'post',
#  599: 'decimal',
#  600: 'busy',
#  601: 'vouchers',
#  602: 'tomo',
#  603: 'bored',
#  604: 'charge',
#  605: 'weekly',
#  606: 'hurt',
#  607: 'sad',
#  608: 'started',
#  609: 'whats',
#  610: 'pics',
#  611: 'change',
#  612: 'date',
#  613: 'thinking',
#  614: 'neva',
#  615: 'colour',
#  616: 'games',
#  617: 'land',
#  618: 'hair',
#  619: 'huh',
#  620: 'rite',
#  621: 'saying',
#  622: 'forget',
#  623: 'taking',
#  624: '500',
#  625: 'break',
#  626: 'points',
#  627: 'took',
#  628: 'å£500',
#  629: 'lose',
#  630: 'beautiful',
#  631: "won't",
#  632: 'anyone',
#  633: 'drop',
#  634: 'w',
#  635: 'lots',
#  636: 'national',
#  637: 'touch',
#  638: 'ring',
#  639: 'lets',
#  640: 'tho',
#  641: '12hrs',
#  642: "she's",
#  643: 'worth',
#  644: 'drink',
#  645: 'smth',
#  646: 'old',
#  647: 'pm',
#  648: 'xx',
#  649: 'found',
#  650: 'calling',
#  651: 'chikku',
#  652: 'question',
#  653: 'gone',
#  654: 'close',
#  655: 'gd',
#  656: 'smiling',
#  657: 'okie',
#  658: '8007',
#  659: 'angry',
#  660: 'email',
#  661: 'simple',
#  662: 'cause',
#  663: 'mine',
#  664: 'minute',
#  665: 'lesson',
#  666: 'drive',
#  667: 'eve',
#  668: 'takes',
#  669: 'darlin',
#  670: 'don',
#  671: 'college',
#  672: 'lovely',
#  673: 'search',
#  674: 'gr8',
#  675: 'fast',
#  676: 'lucky',
#  677: 'whatever',
#  678: 'saturday',
#  679: 'finished',
#  680: '86688',
#  681: 'row',
#  682: 'private',
#  683: 'sis',
#  684: 'each',
#  685: 'awesome',
#  686: 'nope',
#  687: 'available',
#  688: 'comes',
#  689: 'weeks',
#  690: 'smoke',
#  691: 'alone',
#  692: 'mobileupd8',
#  693: 'dreams',
#  694: 'voucher',
#  695: 'everyone',
#  696: 'aft',
#  697: 'poly',
#  698: 'content',
#  699: '30',
#  700: 'msgs',
#  701: 'wil',
#  702: 'head',
#  703: 'operator',
#  704: 'opt',
#  705: 'ltd',
#  706: 'trip',
#  707: 'hard',
#  708: 'visit',
#  709: 'knw',
#  710: '11',
#  711: 'mates',
#  712: 'final',
#  713: 'pobox',
#  714: '750',
#  715: 'chennai',
#  716: 'winner',
#  717: 'noe',
#  718: 'statement',
#  719: 'wonderful',
#  720: 'order',
#  721: 'unsubscribe',
#  722: 'yr',
#  723: 'cum',
#  724: 'girls',
#  725: 'sunday',
#  726: 'rs',
#  727: 'mean',
#  728: 'happened',
#  729: 'fone',
#  730: 'auction',
#  731: 'walk',
#  732: 'far',
#  733: 'pounds',
#  734: 'offers',
#  735: 'whole',
#  736: 'sun',
#  737: 'expires',
#  738: 'savamob',
#  739: 'case',
#  740: '08000839402',
#  741: 'decided',
#  742: 'boytoy',
#  743: 'pub',
#  744: 'prob',
#  745: 'luck',
#  746: 'wrong',
#  747: 'welcome',
#  748: 'å£3',
#  749: 'bout',
#  750: 'company',
#  751: 'earlier',
#  752: 'log',
#  753: "doesn't",
#  754: 'lost',
#  755: 'player',
#  756: '08000930705',
#  757: 'wit',
#  758: 'fucking',
#  759: 'support',
#  760: 'project',
#  761: 'felt',
#  762: 'mate',
#  763: 'dating',
#  764: 'bank',
#  765: 'mum',
#  766: 'hee',
#  767: 'suite342',
#  768: '2lands',
#  769: 'brother',
#  770: 'carlos',
#  771: 'type',
#  772: 'card',
#  773: 'dnt',
#  774: 'father',
#  775: 'snow',
#  776: 'within',
#  777: 'nt',
#  778: 'seeing',
#  779: "you'll",
#  780: 'crazy',
#  781: 'treat',
#  782: 'mayb',
#  783: 'needs',
#  784: 'talking',
#  785: 'second',
#  786: 'kind',
#  787: 'hows',
#  788: 'identifier',
#  789: 'used',
#  790: 'loving',
#  791: 'phones',
#  792: 'tired',
#  793: 'open',
#  794: 'services',
#  795: 'pass',
#  796: 'course',
#  797: 'quiz',
#  798: 'park',
#  799: 'couple',
#  800: 'blue',
#  801: 'outside',
#  802: "'",
#  803: 'press',
#  804: 'darren',
#  805: 'o',
#  806: "you've",
#  807: 'camcorder',
#  808: 'point',
#  809: 'congratulations',
#  810: 'hold',
#  811: 'gas',
#  812: 'å£2',
#  813: '03',
#  814: 'mu',
#  815: 'mom',
#  816: 'understand',
#  817: 'listen',
#  818: 'credit',
#  819: 'tc',
#  820: 'hit',
#  821: 'knew',
#  822: 'almost',
#  823: 'least',
#  824: 'fri',
#  825: 'txts',
#  826: 'fancy',
#  827: 'numbers',
#  828: 'info',
#  829: 'ugh',
#  830: 'frm',
#  831: 'eh',
#  832: 'call2optout',
#  833: 'hungry',
#  834: 'rental',
#  835: 'oredi',
#  836: 'ha',
#  837: 'correct',
#  838: '100',
#  839: 'meant',
#  840: 'reason',
#  841: 'download',
#  842: 'choose',
#  843: 'valued',
#  844: 'difficult',
#  845: 'supposed',
#  846: 'bslvyl',
#  847: 'age',
#  848: 'ten',
#  849: 'st',
#  850: 'etc',
#  851: 'finally',
#  852: 'hmmm',
#  853: 'ni8',
#  854: 'gym',
#  855: 'ago',
#  856: 'direct',
#  857: 'frnd',
#  858: 'yar',
#  859: 'blood',
#  860: 'sister',
#  861: 'entered',
#  862: 'invited',
#  863: 'mah',
#  864: 'caller',
#  865: 'wow',
#  866: 'wonder',
#  867: 'cut',
#  868: 'rest',
#  869: 'fr',
#  870: 'motorola',
#  871: 'tel',
#  872: 'discount',
#  873: 'john',
#  874: 'ans',
#  875: 'å£350',
#  876: 'their',
#  877: 'happiness',
#  878: 'crave',
#  879: 'na',
#  880: 'sea',
#  881: 'sex',
#  882: "wasn't",
#  883: 'clean',
#  884: 'small',
#  885: 'ass',
#  886: 'parents',
#  887: 'swing',
#  888: 'freemsg',
#  889: 'stupid',
#  890: 'uncle',
#  891: 'song',
#  892: 'loved',
#  893: 'ex',
#  894: 'goodmorning',
#  895: 'heard',
#  896: 'telling',
#  897: 'police',
#  898: 'sounds',
#  899: 'wap',
#  900: 'bcoz',
#  901: 'tickets',
#  902: 'ac',
#  903: 'poor',
#  904: 'currently',
#  905: 'friday',
#  906: 'woke',
#  907: 'reached',
#  908: 'hmm',
#  909: 'energy',
#  910: 'surprise',
#  911: 'balance',
#  912: 'asap',
#  913: 'kate',
#  914: 'reading',
#  915: 'callertune',
#  916: 'complimentary',
#  917: 'slow',
#  918: 'information',
#  919: 'usf',
#  920: 'secret',
#  921: '12',
#  922: 'red',
#  923: 'pray',
#  924: "b'day",
#  925: 'askd',
#  926: 'f',
#  927: 'representative',
#  928: 'monday',
#  929: '\x89û',
#  930: 'extra',
#  931: 'questions',
#  932: 'fact',
#  933: '2003',
#  934: 'plans',
#  935: 'anytime',
#  936: '0800',
#  937: 'march',
#  938: 'india',
#  939: "i'd",
#  940: 'gave',
#  941: 'loads',
#  942: 'picking',
#  943: 'mr',
#  944: 'link',
#  945: 'hg',
#  946: 'store',
#  947: '87066',
#  948: 'die',
#  949: 'sort',
#  950: 'save',
#  951: 'abiola',
#  952: 'p',
#  953: 'sell',
#  954: 'confirm',
#  955: 'lovable',
#  956: 'asking',
#  957: 'normal',
#  958: 'doin',
#  959: 'mrng',
#  960: 'rply',
#  961: 'pretty',
#  962: 'frnds',
#  963: 'light',
#  964: 'å£250',
#  965: 'oops',
#  966: 'read',
#  967: 'party',
#  968: 'un',
#  969: 'side',
#  970: 'th',
#  971: "c's",
#  972: 'gettin',
#  973: 'ipod',
#  974: 'std',
#  975: 'sending',
#  976: 'booked',
#  977: 'eg',
#  978: 'il',
#  979: 'truth',
#  980: 'orchard',
#  981: '4u',
#  982: 'laugh',
#  983: 'match',
#  984: 'muz',
#  985: 'valentines',
#  986: 'bathe',
#  987: 'terms',
#  988: 'lessons',
#  989: 'bill',
#  990: 'wana',
#  991: 'å£10',
#  992: 'met',
#  993: 'situation',
#  994: 'unless',
#  995: 'rates',
#  996: 'months',
#  997: 'mobiles',
#  998: 'å£800',
#  999: 'through',
#  1000: 'mon',
#  ...}

# %% [markdown]
# **Creating model and Adding the layers**

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# **Compile the model**

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           260192
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 315,433
# Trainable params: 315,433
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Fit the model**

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 15s 386ms/step - loss: 0.4477 - accuracy: 0.8622 - val_loss: 0.3177 - val_accuracy: 0.8597
# Epoch 2/10
# 30/30 [==============================] - 11s 373ms/step - loss: 0.2156 - accuracy: 0.9285 - val_loss: 0.1472 - val_accuracy: 0.9578

# %% [markdown]
# **Save the model**

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# **Test the model**

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 54ms/step - loss: 0.1166 - accuracy: 0.9785

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.117
#   Accuracy: 0.978
